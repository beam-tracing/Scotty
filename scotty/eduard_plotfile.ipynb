# %%
import matplotlib.pyplot as plt
import numpy as np

# # X_coords = np.linspace(0, 1, 101)
# # Y_coords = np.zeros_like(X_coords)

# # W_0 = 0.05
# # Lambda = 0.01998616
# # X_R = np.pi * W_0**2 / Lambda
# # widths = W_0 * np.sqrt( 1 + (X_coords/X_R)**2 )

# plt.plot(X_coords, Y_coords, color="blue", linestyle="-", linewidth="2.5", label="Cart. Scotty Trajectory")
# plt.plot(X_coords, widths, color="black", linestyle="-", linewidth="1.5", label="Cart. Scotty Beam width")
# plt.plot(X_coords, -widths, color="black", linestyle="-", linewidth="1.5")
# plt.plot(X_coords, Y_coords, color="darkorange", linestyle="--", linewidth="2.5",  label="Analytical Trajectory")
# plt.plot(X_coords, widths, color="darkgray", linestyle="--", linewidth="1.5", label="Analytical Beam width")
# plt.plot(X_coords, -widths, color="darkgray", linestyle="--", linewidth="1.5")
# plt.xlim(0,1)
# plt.xlabel("X-coordinate", fontsize=12, labelpad=10)
# plt.ylim(-0.25, 0.25)
# plt.ylabel("Y-coordinate", fontsize=12, labelpad=10)
# plt.title("Ray Trajectory in Vacuum", fontsize=15, pad=10)
# plt.legend()
# plt.show()

# plt.plot(0, 0, linestyle="-", color="blue", linewidth="2.5", label=fr"Cyl. Scotty $1/R_1$")
# plt.plot(0, 0, linestyle=":", color="red", linewidth="2.5", label=fr"Cart. Scotty $1/R_1$")
# plt.plot(0, 0, linestyle="-", color="darkgreen", linewidth="2.5", label=fr"Cyl. Scotty $1/R_2$")
# plt.plot(0, 0, linestyle=":", color="yellow", linewidth="2.5", label=fr"Cart. Scotty $1/R_2$")
# plt.title(r"Re[$\Psi_{XX}$]", fontsize=15, pad=20)
# plt.legend(fontsize=12)
# plt.xlabel(fr"Arc length relative to cut-off (m)", fontsize=12, labelpad=10)
# plt.ylabel(r"Width $W$ (m)", fontsize=12, labelpad=10)
# plt.show()

# plt.plot(0, 0, linestyle="-", linewidth="2.5", label=r"Cart. Scotty $1/R_1$")
# plt.plot(0, 0, linestyle="-", linewidth="2.5", label=r"Cart. Scotty $1/R_2$")
# plt.title(r"Evolution of beam curvature (beam frame)", fontsize=20, pad=20)
# plt.legend(fontsize=15)
# plt.xlabel(r"Arc length relative to cut-off (m)", fontsize=15, labelpad=10)
# plt.ylabel(r"Curvature, $1/R$ (m$^{-1}$)", fontsize=15, labelpad=10)
# plt.show()
# plt.plot(0, 0, linestyle="-", linewidth="2.5", label=r"Cart. Scotty $W_1$")
# plt.plot(0, 0, linestyle="-", linewidth="2.5", label=r"Cart. Scotty $W_2$")
# plt.title(r"Evolution of beam width (beam frame)", fontsize=20, pad=20)
# plt.legend(fontsize=15)
# plt.xlabel(r"Arc length relative to cut-off (m)", fontsize=15, labelpad=10)
# plt.ylabel(r"Width, $W$ (m)", fontsize=15, labelpad=10)
# plt.show()

# plt.plot(-6, 4, linestyle="-") #, linewidth="2.5", label=r"Cart. Scotty $W_1$")
# plt.plot(0, 20, linestyle="-") #, linewidth="2.5", label=r"Cart. Scotty $W_2$")
# plt.plot(0, 0, linestyle="-", marker="o", color="black", linewidth="1", label=r"Chosen simulations")
# plt.xlabel(r"Toroidal Angle ($^\circ$)", fontsize=15, labelpad=10)
# plt.ylabel(r"Poloidal Angle ($^\circ$)", fontsize=15, labelpad=15)
# plt.title(r"Heatmap of mismatch angle $\theta_m$ ($^\circ$)", fontsize=20, pad=20)
# plt.xlim(-6, 0)
# plt.ylim(4, 20)
# plt.rc("axes", labelsize=12)
# plt.legend(fontsize=15)
# plt.show()
# plt.plot(0, 0, linestyle="-", marker="o", color="black", linewidth="1", label=r"Chosen simulations")
# plt.xlabel(r"Toroidal Angle ($^\circ$)", fontsize=15, labelpad=10)
# plt.ylabel(r"Poloidal Angle ($^\circ$)", fontsize=15, labelpad=15)
# plt.title(r"Heatmap of mismatch angle $\theta_m$ ($^\circ$)", fontsize=20, pad=20)
# plt.xlim(-6, 0)
# plt.ylim(-0.3, 0.3)
# plt.rc("axes", labelsize=12)
# plt.legend(fontsize=15)
# plt.show()

# plt.plot(0, 0, linestyle="-", color="red", linewidth="3", label=r"Central Ray")
# plt.plot(0, 0, linestyle="-", color="black", linewidth="1.5", label=r"Beam width")
# plt.title(r"Ray Trajectory in Stellarator" + "\n" + r"$\alpha_{pol}=10^\circ, \alpha_{tor}=-2.8^\circ$", fontsize=15, pad=20)
# plt.xlim(6, 6.25)
# plt.ylim(-0.3, 0.1)
# plt.rc("xtick", labelsize=12)
# plt.rc("ytick", labelsize=12)
# plt.legend(fontsize=12)
# plt.show()
# plt.plot(0, 0, linestyle="-", color="red", linewidth="3", label=r"Central Ray")
# plt.plot(0, 0, linestyle="-", color="black", linewidth="1.5", label=r"Beam width")
# plt.title(r"Ray Trajectory in Stellarator" + "\n" + r"$\alpha_{pol}=30^\circ, \alpha_{tor}=-8.8^\circ$", fontsize=15, pad=20)
# plt.xlim(6, 6.25)
# plt.ylim(-0.3, 0.1)
# plt.rc("xtick", labelsize=12)
# plt.rc("ytick", labelsize=12)
# plt.legend(fontsize=12)
# plt.show()

# import numpy as np
# import matplotlib.pyplot as plt
# import os
# # Define the directory path
# directory = r"C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\University\FYP\2. Final Report\Figures\G. Results\3. stellarator\temp"
# # Helper function to read file and return coordinates
# def read_coordinates(filename):
#     path = os.path.join(directory, filename)
#     data = np.loadtxt(path, delimiter=',')
#     x = data[:, 0]
#     y = data[:, 1]
#     return x, y
# # Read each file
# x_left, y_left = read_coordinates('left.txt')
# x_centre, y_centre = read_coordinates('centre.txt')
# x_right, y_right = read_coordinates('right.txt')
# # Plot the data
# plt.figure(figsize=(4.2, 5.65))
# plt.plot(x_left, y_left, label='Left', marker='', linestyle="-", linewidth=1, color='black')
# plt.plot(x_centre, y_centre, label='Centre', marker='', linestyle="-", linewidth=2, color='red')
# plt.plot(x_right, y_right, label='Right', marker='', linestyle="-", linewidth=1, color='black')
# plt.xlabel('X Coordinate')
# plt.ylabel('Y Coordinate')
# plt.title('Stellarator Coordinates')
# plt.xlim(6,6.25)
# plt.ylim(-0.3, 0.1)
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

def mpl_3d_beam(X, Y, Z, w1, w2, n_theta=60, elev=20, azim=30):
    """
    Plot a 3D beam profile whose cross-section is an ellipse
    perpendicular to an arbitrary ray trajectory.

    Parameters
    ----------
    X, Y, Z : arrays
        Coordinates of the central ray
    w1, w2 : arrays
        Beam widths in the two orthogonal transverse directions
    n_theta : int
        Resolution of ellipse cross-section
    elev, azim : float
        Viewing angles
    """

    X = np.array(X)
    Y = np.array(Y)
    Z = np.array(Z)
    w1 = np.array(w1)
    w2 = np.array(w2)

    # --- 1. Compute the ray tangent vector ---
    dX = np.gradient(X)
    dY = np.gradient(Y)
    dZ = np.gradient(Z)
    T = np.vstack([dX, dY, dZ]).T
    T_norm = np.linalg.norm(T, axis=1)
    T = T / T_norm[:, None]   # normalize

    # --- 2. Build perpendicular frame (N, B) ---
    # Pick arbitrary reference vector not parallel to T
    ref = np.array([0, 0, 1])
    N = np.cross(T, ref)
    small = np.linalg.norm(N, axis=1) < 1e-6
    N[small] = np.cross(T[small], np.array([0, 1, 0]))
    N = N / np.linalg.norm(N, axis=1)[:, None]

    B = np.cross(T, N)
    B = B / np.linalg.norm(B, axis=1)[:, None]

    # --- 3. Parametric ellipse around ray ---
    theta = np.linspace(0, 2 * np.pi, n_theta)
    beam_surfaces = []

    for i in range(len(X)):
        # ellipse point coordinates in global space
        xi = X[i] + w1[i] * np.cos(theta) * N[i, 0] + w2[i] * np.sin(theta) * B[i, 0]
        yi = Y[i] + w1[i] * np.cos(theta) * N[i, 1] + w2[i] * np.sin(theta) * B[i, 1]
        zi = Z[i] + w1[i] * np.cos(theta) * N[i, 2] + w2[i] * np.sin(theta) * B[i, 2]
        beam_surfaces.append(np.vstack([xi, yi, zi]).T)

    # --- 4. Plot ---
    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')

    # Plot the beam surface as quads
    verts = []
    for i in range(len(beam_surfaces) - 1):
        for j in range(n_theta - 1):
            quad = [
                beam_surfaces[i][j],
                beam_surfaces[i][j+1],
                beam_surfaces[i+1][j+1],
                beam_surfaces[i+1][j]
            ]
            verts.append(quad)

    poly = Poly3DCollection(verts, alpha=0.6, facecolor='red', edgecolor='none')
    ax.add_collection3d(poly)

    # Plot ray center line
    ax.plot(X, Y, Z, color='red', linewidth=2, label="Ray")

    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_zlabel("Z")
    ax.view_init(elev=elev, azim=azim)
    ax.set_title("3D Beam Profile Along Ray (Elliptical Cross-Sections)")
    plt.tight_layout()
    plt.show()


# -----------------------------------------------------------------
# Example usage:
if __name__ == "__main__":
    z = np.linspace(0, 10, 200)
    X = 0.1 * np.sin(0.3 * z)
    Y = 0.1 * np.cos(0.3 * z)
    Z = z
    w1 = 0.05 * (1 + 0.3 * np.sin(z))
    w2 = 0.08 * (1 + 0.2 * np.cos(z))

    plot_3d_beam(X, Y, Z, w1, w2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 99
#      96 w1 = 0.05 * (1 + 0.3 * np.sin(z))
#      97 w2 = 0.08 * (1 + 0.2 * np.cos(z))
# ---> 99 plot_3d_beam(X, Y, Z, w1, w2)
#
# NameError: name 'plot_3d_beam' is not defined

# %%
import numpy as np
import plotly.graph_objects as go
import plotly.io as pio
from scotty.geometry import MagneticField
from scotty.geometry_3D import MagneticField_Cartesian

def plotly_3d_beam(
        tau, cutoff_index,
        q_X, q_Y, q_Z,
        width1, width2,
        n_hat, bn_hat,
        field=None,
        N_theta=360,
        render_env="browser",
        **plot_kwargs,
    ):

    """
    Vectorized 3D beam visualization using Plotly Mesh3d.

    field          : MagneticField_Cartesian
    q_X, q_Y, q_Z  : (N,) ray coordinates
    width1, width2 : (N,) beam radii along n_hat and bn_hat
    n_hat, bn_hat  : (N,3) normal and binormal unit vectors
    N_theta        : int mesh resolution for the beam cross-section ellipse
    render_env     : str rendering environment
    plot_kwargs    : dictionary of keyword arguments used for plotting the beam
    """

    pio.renderers.default = render_env

    cutoff_idx = int(cutoff_index)
    tau = np.asarray(tau)
    q_X = np.asarray(q_X)
    q_Y = np.asarray(q_Y)
    q_Z = np.asarray(q_Z)
    width1 = np.asarray(width1)
    width2 = np.asarray(width2)
    n_hat  = np.asarray(n_hat)
    bn_hat = np.asarray(bn_hat)

    # TO REMOVE -- put this directly into analysis.py
    # so that the widths are always fixed
    start_idx = 10
    width_diff = np.abs(width1[start_idx:] - width2[start_idx:])
    switch_idx = start_idx + np.argmin(width_diff)
    new_width1 = np.concatenate((width1[:switch_idx], width2[switch_idx:]))
    new_width2 = np.concatenate((width2[:switch_idx], width1[switch_idx:]))
    width1 = np.copy(new_width1)
    width2 = np.copy(new_width2)

    # Vectorise the ellipse generation by adding
    # [None, :] for sin and cos to make their shapes
    # (1, len(theta)); and [:, None] for q_X, q_Y, q_Z,
    # width1, width2 to make their shapes (len(q_X), 1).
    # Then compute the coordinates of the surface with
    # shape (len(q_X), len(theta))

    theta = np.linspace(0, 2*np.pi, N_theta)

    # shape (1, T)
    None_sin_th = np.sin(theta)[None, :]
    None_cos_th = np.cos(theta)[None, :]

    # shape (Q, 1)
    q_X_None = q_X[:, None]
    q_Y_None = q_Y[:, None]
    q_Z_None = q_Z[:, None]
    width1_None = width1[:, None]
    width2_None = width2[:, None]

    # shape (Q, T)
    # hats are sliced as [:, a:b] to make them column vectors
    q_Xi = q_X_None + (width1_None * None_cos_th * n_hat[:,0:1]) + (width2_None * None_sin_th * bn_hat[:,0:1])
    q_Yi = q_Y_None + (width1_None * None_cos_th * n_hat[:,1:2]) + (width2_None * None_sin_th * bn_hat[:,1:2])
    q_Zi = q_Z_None + (width1_None * None_cos_th * n_hat[:,2:3]) + (width2_None * None_sin_th * bn_hat[:,2:3])

    q_Xi_bef, q_Xi_aft = q_Xi[:cutoff_idx], q_Xi[cutoff_idx:]
    q_Yi_bef, q_Yi_aft = q_Yi[:cutoff_idx], q_Yi[cutoff_idx:]
    q_Zi_bef, q_Zi_aft = q_Zi[:cutoff_idx], q_Zi[cutoff_idx:]

    def plot_beam_in_parts(q_Xi_toplot, q_Yi_toplot, q_Zi_toplot):
        q_Xi_ravel = q_Xi_toplot.ravel()
        q_Yi_ravel = q_Yi_toplot.ravel()
        q_Zi_ravel = q_Zi_toplot.ravel()

        # Now we construct the triangle indices of the 3d mesh with
        # grid indices I, J, where I is the index going from
        # 0 to len(q_X) and J is the index going from 0 to len(theta).
        # The quad(-ilateral) faces can be split into two triangles,
        # which we call `tr1` and `tr2`, whose vertices are ordered like:
        #    (i,j) -> (i, j+1)   -> (i+1, j+1)
        #    (i,j) -> (i+1, j+1) -> (i+1, j)
        # We then stack the vertices together to be passed onto the
        # plotter. We call these `trs`.
        #
        # Note: In constructing the meshgrids II and JJ, we take the
        # indices to run until len(...)-1. This is because our
        # calculations already account for that last point (with `+1`s).

        numQ, numT = q_Xi.shape
        I = np.arange(numQ)
        J = np.arange(numT)
        II, JJ = np.meshgrid(I[:-1], J[:-1], indexing="ij")
        II = II.ravel()
        JJ = JJ.ravel()

        tr1_v1 = tr2_v1 = numT*II + JJ
        tr1_v2 = numT* II    + (JJ+1)
        tr1_v3 = numT*(II+1) + (JJ+1)
        tr2_v2 = numT*(II+1) + (JJ+1)
        tr2_v3 = numT*(II+1) +  JJ

        trs_v1 = np.concatenate([tr1_v1, tr2_v1])
        trs_v2 = np.concatenate([tr1_v2, tr2_v2])
        trs_v3 = np.concatenate([tr1_v3, tr2_v3])

        # Plotting the central ray and beam widths
        ray_color    = plot_kwargs.pop("ray_color", "black")
        ray_width    = plot_kwargs.pop("ray_linewidth", 5)
        beam_color   = plot_kwargs.pop("beam_color", "black")
        beam_opacity = plot_kwargs.pop("beam_opacity", 0.35)

        fig = go.Figure()

        fig.add_trace(go.Scatter3d(
            x=q_X,
            y=q_Y,
            z=q_Z,
            mode="lines",
            line={"color": ray_color, "width": ray_width},
            name="Central Ray",
            showlegend=False
        ))

        fig.add_trace(go.Mesh3d(
            x=q_Xi_ravel,
            y=q_Yi_ravel,
            z=q_Zi_ravel,
            i=trs_v1,
            j=trs_v2,
            k=trs_v3,
            color=beam_color,
            opacity=beam_opacity,
            name="Beam",
            showlegend=False
        ))

        # Putting the metadata in the plot
        plot_title = plot_kwargs.pop("plot_title", "3d Ray and Beam Tracing Plot")
        plot_width = plot_kwargs.pop("plot_width", 1400)
        plot_height = plot_kwargs.pop("plot_height", 700)

        scene = {
            "xaxis_title": "X [m]",
            "yaxis_title": "Y [m]",
            "zaxis_title": "Z [m]",
            "aspectmode": "data", # equal aspect ratio
        }

        ax_lims = {"x": plot_kwargs.pop("xlim", None),
                "y": plot_kwargs.pop("ylim", None),
                "z": plot_kwargs.pop("zlim", None)}
        
        ax_lims_pad = {"x": abs(plot_kwargs.pop("xpad", 0.1)),
                    "y": abs(plot_kwargs.pop("ypad", 0.1)),
                    "z": abs(plot_kwargs.pop("zpad", 0.1))}
        
        # If the user does not specify axis limits, construct them ourselves
        # Otherwise just use the user's
        for name, lim in ax_lims.items():
            _pad = ax_lims_pad[name]
            if lim == None or not (isinstance(lim, tuple) and len(lim) == 2):
                # TO REMOVE -- insert log message
                lim = np.array([], dtype=float)
                for trace in fig.data: lim = np.concatenate((lim, np.array(trace[name])))
            
            min_lim = round(min(lim) - _pad, 1)
            max_lim = round(max(lim) + _pad, 1)
            ax_lims[name] = [min_lim, max_lim]
            scene[f"{name}axis"] = {"range": [min_lim, max_lim]}
        
        # Plotting the nested flux surfaces
        isomin = plot_kwargs.pop("rho_flux_min", 0.0)
        isomax = plot_kwargs.pop("rho_flux_min", 1.0)
        isonum = plot_kwargs.pop("rho_flux_levels", 11)
        isopacity = plot_kwargs.pop("rho_flux_opacity", 0.1)
        isocolor = plot_kwargs.pop("rho_flux_opacity", "plasma_r")
        isolvl = np.linspace(isomin, isomax, isonum)

        def get_linspace(min_max_tuple): return np.linspace(min_max_tuple[0], min_max_tuple[1], round((min_max_tuple[1] - min_max_tuple[0]) / 0.01) + 1)

        if field != None and isinstance(field, (MagneticField, MagneticField_Cartesian)):
            X = get_linspace(ax_lims["x"])
            Y = get_linspace(ax_lims["y"])
            Z = get_linspace(ax_lims["z"])
            XX, YY, ZZ = np.meshgrid(X, Y, Z, indexing="ij")
            
            if isinstance(field, MagneticField):
                RR = np.sqrt(XX**2 + YY**2)
                rho_mesh = np.sqrt(np.abs(field.poloidal_flux(RR, ZZ)))
                q_Ri_ravel = np.sqrt(q_Xi_ravel**2 + q_Yi_ravel**2)
                rho_beam_envelope_mesh = np.sqrt(field.poloidal_flux(q_Ri_ravel, q_Zi_ravel))
            elif isinstance(field, MagneticField_Cartesian):
                rho_mesh = np.sqrt(field.polflux(XX, YY, ZZ))
                rho_beam_envelope_mesh = np.sqrt(field.polflux(q_Xi_ravel, q_Yi_ravel, q_Zi_ravel))

            fig.add_trace(go.Isosurface(
                x=XX.ravel(),
                y=YY.ravel(),
                z=ZZ.ravel(),
                value=rho_mesh.ravel(),
                isomin=isomin,
                isomax=isomax,
                surface_count=isonum,
                opacity=isopacity,
                colorscale=isocolor,
                caps={"x_show": False, "y_show": False, "z_show": False},
                name="Flux Surfaces",
            ))

            def get_mask(lvl, tol=0.001):
                for _ in range(15):
                    mask = np.abs(rho_beam_envelope_mesh - lvl) < tol
                    check = q_Xi_ravel[mask]
                    if   check.size < 10:  tol += tol*0.1
                    elif check.size > 720: tol -= tol*0.1
                    else: break
                return mask
            
            import plotly.colors as pc
            for lvl in isolvl:
                mask = get_mask(lvl)
                q_Xi_ravel_masked = q_Xi_ravel[mask]
                q_Yi_ravel_masked = q_Yi_ravel[mask]
                q_Zi_ravel_masked = q_Zi_ravel[mask]
                plasma_colours = pc.sequential.Plasma_r
                color = plasma_colours[int(lvl * (len(plasma_colours) - 1))]

                fig.add_trace(go.Scatter3d(
                    x=q_Xi_ravel_masked,
                    y=q_Yi_ravel_masked,
                    z=q_Zi_ravel_masked,
                    mode="markers",
                    marker={"size": 5, "opacity": 1, "color": color},
                    showlegend=False
                ))

                print("lvl and size", lvl, q_Xi_ravel_masked.size)
            
            fig.update_layout(
                title=plot_title,
                scene=scene,
                width=plot_width,
                height=plot_height,
            )

            fig.show()

    # plot_beam_in_parts(q_Xi_bef, q_Yi_bef, q_Zi_bef)
    # plot_beam_in_parts(q_Xi_aft, q_Yi_aft, q_Zi_aft)
    plot_beam_in_parts(q_Xi, q_Yi, q_Zi)





import h5py
from pathlib import Path
from scotty.beam_me_up import create_magnetic_geometry

def read_h5():
    data_dir = Path(r"C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\DIII-D shot 189998\cart scotty\scotty_output.h5")
    # data_dir = Path(r"C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\MAST-U\cart scotty\scotty_output.h5")

    with h5py.File(data_dir, "r") as f:
        d = {}
        for k in ["tau", "cutoff_index", "q_X", "q_Y", "q_Z", "beam_width_1", "beam_width_2", "x_hat", "y_hat"]:
            try:    _temp = np.array(f["solver_output"][k])
            except: _temp = np.array(f["analysis"][k])
            d[k] = _temp
        
        # print(d.keys())

        d["field"] = create_magnetic_geometry(
            find_B_method="omfit",
            magnetic_data_path=Path(fr"C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\DIII-D shot 189998\cyl scotty"),
            input_filename_suffix=f"_189998_3000ms_quinn",
            # magnetic_data_path=Path(fr"C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\MAST-U\cyl scotty"),
            # input_filename_suffix=f"_51353_410ms_1.0",
            interp_order=5,
            interp_smoothing=0,
        )

        print(np.array(f["inputs"]["poloidal_launch_angle_Torbeam"]))
        print(np.array(f["inputs"]["poloidal_launch_angle_Torbeam"]))

        return d





def test_plot():
    d = read_h5()
    plotly_3d_beam(*d.values())



test_plot()
# Out:
# Using OMFIT JSON Torbeam file for B and poloidal flux
# -5.0
# -5.0
# lvl and size 0.0 0
# lvl and size 0.1 0
# lvl and size 0.2 0
# lvl and size 0.30000000000000004 0
# lvl and size 0.4 0
# lvl and size 0.5 0
# lvl and size 0.6000000000000001 668
# lvl and size 0.7000000000000001 900
# lvl and size 0.8 720
# lvl and size 0.9 673
# lvl and size 1.0 71

# %%
def read_h5():
    data_dir = Path(r"C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\MAST-U\tgt\cart\scotty_output.h5")

    with h5py.File(data_dir, "r") as f:
        print(f.attrs.keys())
        print(f["inputs"].coords)

read_h5()
# Out:
# <KeysViewHDF5 ['title', 'software_name', 'software_version', 'date_created', 'id']>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 8
#       5         print(f.attrs.keys())
#       6         print(f["inputs"].coords)
# ----> 8 read_h5()
#
# Cell In[50], line 6, in read_h5()
#       4 with h5py.File(data_dir, "r") as f:
#       5     print(f.attrs.keys())
# ----> 6     print(f["inputs"].coords)
#
# AttributeError: 'Group' object has no attribute 'coords'

# %% [markdown]
# ### Plot 3d beam profile

# %%
from datatree import DataTree
from scotty.typing import PathLike
from typing import Optional
from matplotlib.widgets import Slider
import numpy as np

from scotty.fun_general import find_q_lab_Cartesian

def plot_3D_beam_profile_3D_plotting(
    dt: DataTree,
    filename: Optional[PathLike] = None,
    include_p: Optional = False,
    include_s: Optional = False,
    include_b: Optional = False,
    include_r: Optional = False,
    include_m: Optional = False,
):
    """
    Plots a 3D plot of the Beam profile, along with:
    - Eigenvector plot showing the beam width axis
    - Width of the beam along the ray
    - Curvature of the beam along the ray
    - localisations
    """
    # include_...: whether or not to mutliply these values in the localisation graph
    # eg. include_p & include_s True -> plot graph of loc_p * loc_s against distance

    include_width1 = True  # green beam width
    include_width2 = True  # red beam width

    include_title = True
    title_additional_notes = ""
    thresh_gradgrad = 100.0
    thresh_intersect = 100.0
    window_size = 0.01
    ellipse_resolution = 30

    ##extracting inputs
    title_shot = 189998
    title_time = 3005
    title_mode = dt.inputs.mode_flag.data
    title_freq = dt.inputs.launch_freq_GHz.data
    title_pol = dt.inputs.poloidal_launch_angle_Torbeam
    title_tor = dt.inputs.toroidal_launch_angle_Torbeam
    title_width = dt.inputs.launch_beam_width
    title_curv = dt.inputs.launch_beam_curvature

    # For the 3D Axes, will need the limits of the path, with some leeway for the beam
    # note to self, capital coordinates are lab, cylindrical coordinates
    tau_array = np.array(dt.solver_output.tau)
    q_X_array = np.array(dt.solver_output.q_X)
    q_Y_array = np.array(dt.solver_output.q_Y)
    q_Z_array = np.array(dt.solver_output.q_Z)
    poloidal_flux_output = np.array(dt.analysis.polflux)

    # Here we can calculate the linestep, but importing the array is simpler
    distance_along_line = dt.analysis.arc_length.data

    # Here we import the arrays necessary to calculate the beam shape
    Psi_xx_output = np.array(dt.analysis.Psi_xx_beamframe_cartesian)
    Psi_xy_output = np.array(dt.analysis.Psi_xy_beamframe_cartesian)
    Psi_yy_output = np.array(dt.analysis.Psi_yy_beamframe_cartesian)
    x_hat_Cartesian = np.array(dt.analysis.x_hat)
    y_hat_Cartesian = np.array(dt.analysis.y_hat)
    g_hat_Cartesian = np.array(dt.analysis.g_hat)
    K_magnitude_array = np.array(dt.solver_output.K_magnitude)
    theta_output = np.array(dt.analysis.theta)
    theta_m_output = np.array(dt.analysis.theta_m)
    cutoff_index = dt.analysis.cutoff_index.data

    ##for calculating product of localisations:
    loc_p = np.array(dt.analysis.loc_p)
    loc_r = np.array(dt.analysis.loc_r)
    loc_b = np.array(dt.analysis.loc_b)
    loc_m = np.array(dt.analysis.loc_m)
    loc_s = np.array(dt.analysis["loc_s_-10_3"])

    # ==================================================================================#
    # Code to find the necessary arrays to plot

    numberOfDataPoints = np.size(q_X_array)
    out_index = numberOfDataPoints - 1
    ##setting up the psi_w arrays, separating real and imaginary parts
    Psi_w_real = np.array(
        np.real([[Psi_xx_output, Psi_xy_output], [Psi_xy_output, Psi_yy_output]])
    )
    Psi_w_imag = np.array(
        np.imag([[Psi_xx_output, Psi_xy_output], [Psi_xy_output, Psi_yy_output]])
    )

    eigvals_im, eigvecs_im = np.linalg.eigh(np.moveaxis(Psi_w_imag, -1, 0))
    # Note the issue with function is that when the eigenvalues intersect, they might be switched around
    widths = np.sqrt(2 / eigvals_im)
    width1 = np.copy(widths[:, 0])
    width2 = np.copy(widths[:, 1])

    eigvec1_x = np.copy(eigvecs_im[:, 0, 0])
    eigvec1_y = np.copy(eigvecs_im[:, 0, 1])

    eigvec2_x = np.copy(eigvecs_im[:, 1, 0])
    eigvec2_y = np.copy(eigvecs_im[:, 1, 1])

    # Following code is to switch the eigenvalues/eigenvalues back
    gradgrad_width1 = np.gradient(
        np.gradient(width1, distance_along_line), distance_along_line
    )

    idx_switch_im = np.argmax(gradgrad_width1)

    if gradgrad_width1[idx_switch_im] > thresh_gradgrad * np.mean(gradgrad_width1):
        if (
            abs(width1[idx_switch_im] - width2[idx_switch_im])
            < np.mean(width1) / thresh_intersect
        ):
            for i in range(idx_switch_im, len(width1)):
                width1[i] = widths[i, 1]
                width2[i] = widths[i, 0]
                eigvec1_x[i] = eigvecs_im[i, 1, 0]
                eigvec1_y[i] = eigvecs_im[i, 1, 1]
                eigvec2_x[i] = eigvecs_im[i, 0, 0]
                eigvec2_y[i] = eigvecs_im[i, 0, 1]

    # principal vectors in terms of Lab Cartesian Coordinates

    pvec1 = np.zeros((numberOfDataPoints, 3))
    pvec2 = np.zeros((numberOfDataPoints, 3))

    for i in range(numberOfDataPoints):
        pvec1[i] = width1[i] * (
            eigvec1_x[i] * x_hat_Cartesian[i] + eigvec1_y[i] * y_hat_Cartesian[i]
        )
        pvec2[i] = width2[i] * (
            eigvec2_x[i] * x_hat_Cartesian[i] + eigvec2_y[i] * y_hat_Cartesian[i]
        )

    curv1 = np.zeros([numberOfDataPoints])
    curv2 = np.zeros([numberOfDataPoints])

    eigvals_re, eigvecs_re = np.linalg.eigh(np.moveaxis(Psi_w_real, -1, 0))

    curv1 = (eigvals_re[:, 0] / K_magnitude_array) * (
        np.cos(theta_output + theta_m_output)
    ) ** 2
    curv2 = (eigvals_re[:, 1] / K_magnitude_array) * (
        np.cos(theta_output + theta_m_output)
    ) ** 2
    curv1_temp = np.copy(curv1)
    curv2_temp = np.copy(curv2)

    gradgrad_curv1 = np.gradient(
        np.gradient(curv1, distance_along_line), distance_along_line
    )

    idx_switch_re = np.argmax(gradgrad_curv1)

    if gradgrad_curv1[idx_switch_re] > thresh_gradgrad * np.mean(gradgrad_curv1):
        if (
            abs(curv1[idx_switch_re] - curv2[idx_switch_re])
            < np.mean(np.abs(curv1)) / thresh_intersect
        ):
            for i in range(idx_switch_re, len(curv1)):
                curv1[i] = curv2_temp[i]
                curv2[i] = curv1_temp[i]

    # ==================================================================================#
    # Setting the Main Plot
    px = 1 / plt.rcParams["figure.dpi"]  # defining pixels
    fig = plt.figure(
        tight_layout=True, figsize=(1600 * px, 800 * px), num="3D Beam Propagation"
    )

    title = ""
    if include_title:
        title += f"\nshot = {title_shot}"
        title += f"\ntime = {title_time}ms"
        title += f"\nmode = {title_mode}"
        title += f"\nfreq = {title_freq:.1f}GHz"
        title += f"\npol = {title_pol:.1f}\u00B0"
        title += f"\ntor = {title_tor:.1f}\u00B0"
        title += f"\nwidth = {title_width:.3f}m"
        title += f"\ncurv = {title_curv:.3f}" + r"$m^{-1}$"
        title += f"\n{title_additional_notes}"

    fig.text(
        0.05, 0.78, title, ha="center"
    )  # Note the positions are for the bottom left corner of the text

    # fig refers to the entire window, each axes refers to a specific graph within the entire figure

    ax = plt.subplot2grid(
        (4, 8), (0, 0), colspan=4, rowspan=4, projection="3d"
    )  # initialise the plot

    ax.plot(
        q_X_array, q_Y_array, q_Z_array, label="Central Ray", lw=5, color="blue"
    )  # plot the trajectory of the central ray

    ax.scatter(
        [q_X_array[0]], [q_Y_array[0]], [q_Z_array[0]], marker="o", s=50, color="black"
    )  # plots starting point

    arrow_vec = g_hat_Cartesian[out_index]
    ax.quiver(
        q_X_array[out_index],
        q_Y_array[out_index],
        q_Z_array[out_index],
        arrow_vec[0],
        arrow_vec[1],
        arrow_vec[2],
        length=0.01,
        arrow_length_ratio=3,
        linewidth=5.0,
        normalize=True,
        color="blue",
    )  # add an arrow at the end of the ray trajectory to tell users how ray is travelling

    ##resizing stuff
    length_required = np.array(
        [
            np.max(q_X_array) - np.min(q_X_array),
            np.max(q_Y_array) - np.min(q_Y_array),
            np.max(q_Z_array) - np.min(q_Z_array),
        ]
    )
    max_width = np.max(length_required)

    x_window = (max_width - length_required[0]) / 2 + window_size
    y_window = (max_width - length_required[1]) / 2 + window_size
    z_window = (max_width - length_required[2]) / 2 + window_size

    # Subsequent settings are to ensure that the lengths are the same

    ax.set_xlim(np.min(q_X_array) - x_window, np.max(q_X_array) + x_window)
    ax.set_ylim(np.min(q_Y_array) - y_window, np.max(q_Y_array) + y_window)
    ax.set_zlim(np.min(q_Z_array) - z_window, np.max(q_Z_array) + z_window)

    ax.set_box_aspect([1, 1, 1])

    ax.set_xlabel("X/m")
    ax.set_ylabel("Y/m")
    ax.set_zlabel("Z/m")
    ax.legend()

    # ==================================================================================#
    # Plotting the beam surface
    # We can use the coordinates here for the interactive ellipse to be plotted

    X_beam_surface = np.zeros([numberOfDataPoints, ellipse_resolution + 1])
    Y_beam_surface = np.zeros([numberOfDataPoints, ellipse_resolution + 1])
    Z_beam_surface = np.zeros([numberOfDataPoints, ellipse_resolution + 1])

    theta = np.concatenate(
        (np.arange(0, 2 * np.pi, (2 * np.pi / ellipse_resolution)), [0.0]), axis=0
    )

    cos_theta_array = np.cos(theta)
    sin_theta_array = np.sin(theta)

    for idx1 in range(numberOfDataPoints):
        for idx2 in range(ellipse_resolution + 1):

            w1 = pvec1[idx1] * cos_theta_array[idx2]
            w2 = pvec2[idx1] * sin_theta_array[idx2]

            X_beam_surface[idx1][idx2] = w1[0] + w2[0] + q_X_array[idx1]
            Y_beam_surface[idx1][idx2] = w1[1] + w2[1] + q_Y_array[idx1]
            Z_beam_surface[idx1][idx2] = w1[2] + w2[2] + q_Z_array[idx1]

    ax.plot_surface(
        X_beam_surface,
        Y_beam_surface,
        Z_beam_surface,
        edgecolor="royalblue",
        lw=0.04,
        rstride=4,
        cstride=4,
        alpha=0.01,
    )  # plot the beam surface

    # ==================================================================================#
    # Plotting the x and y hat planes
    # We first find the magnitude to be plotted, which we want to be such that this plane, stretches exactly to the beam_surface
    # The is some simple trigo
    mag_x_plane = np.sqrt((width1 * eigvec1_x) ** 2 + (width2 * eigvec2_x) ** 2)
    mag_y_plane = np.sqrt((width1 * eigvec1_y) ** 2 + (width2 * eigvec2_y) ** 2)

    x_plane = np.zeros([numberOfDataPoints, 2, 3])
    y_plane = np.zeros([numberOfDataPoints, 2, 3])

    for idx1 in range(numberOfDataPoints):
        cray_pos = np.array(
            [q_X_array[idx1], q_Y_array[idx1], q_Z_array[idx1]]
        )  # I couldnt think of a better name, but its simply central ray position
        x_plane[idx1][0] = -mag_x_plane[idx1] * x_hat_Cartesian[idx1] + cray_pos
        x_plane[idx1][1] = mag_x_plane[idx1] * x_hat_Cartesian[idx1] + cray_pos
        y_plane[idx1][0] = -mag_y_plane[idx1] * y_hat_Cartesian[idx1] + cray_pos
        y_plane[idx1][1] = mag_y_plane[idx1] * y_hat_Cartesian[idx1] + cray_pos

    colorx = "green"
    colory = "red"

    ax.plot_surface(
        x_plane[:, :, 0],
        x_plane[:, :, 1],
        x_plane[:, :, 2],
        edgecolor=colorx,
        lw=0.04,
        rstride=4,
        cstride=4,
        color=colorx,
        alpha=0.1,
    )  # plot the x_hat plane
    ax.plot_surface(
        y_plane[:, :, 0],
        y_plane[:, :, 1],
        y_plane[:, :, 2],
        edgecolor=colory,
        lw=0.04,
        rstride=4,
        cstride=4,
        color=colory,
        alpha=0.1,
    )  # plot the y_hat plane
    # ==================================================================================#
    # Setting the required functions
    # For the initial poss, and slider updating

    def index_pos(distance):
        # print(np.abs(distance_along_line - distance))
        index_pos = np.argmin(np.abs(distance_along_line - distance))
        return index_pos

    def dot_pos(distance):
        index_pos = np.argmin(np.abs(distance_along_line - distance))
        return [q_X_array[index_pos], q_Y_array[index_pos], q_Z_array[index_pos]]

    # ==================================================================================#
    # Initial conditions

    init_distance = distance_along_line[cutoff_index]

    # Dot on the path
    (dot,) = ax.plot(
        dot_pos(init_distance)[0],
        dot_pos(init_distance)[1],
        dot_pos(init_distance)[2],
        "ro",
        markersize=10,
        color="black",
    )  # initialise the moveable point to be at the cutoff point

    (dot_cutoff,) = ax.plot(
        dot_pos(init_distance)[0],
        dot_pos(init_distance)[1],
        dot_pos(init_distance)[2],
        "ro",
        markersize=15,
        color="red",
    )  # mark out where the cutoff point is located

    pvec1_init_pos = pvec1[index_pos(init_distance)]
    pvec2_init_pos = pvec2[index_pos(init_distance)]

    # Line linking dot on the path to dot pointing along pvec1
    line_pvec1_init_pos = [
        (
            dot_pos(init_distance)[0] - pvec1_init_pos[0],
            dot_pos(init_distance)[1] - pvec1_init_pos[1],
            dot_pos(init_distance)[2] - pvec1_init_pos[2],
        ),
        (
            dot_pos(init_distance)[0] + pvec1_init_pos[0],
            dot_pos(init_distance)[1] + pvec1_init_pos[1],
            dot_pos(init_distance)[2] + pvec1_init_pos[2],
        ),
    ]
    line_pvec1 = ax.plot(*zip(*line_pvec1_init_pos))[0]
    line_pvec1.set_color("green")
    line_pvec1.set_linewidth(3.0)

    # Line linking dot on the path to dot pointing along pvec2
    line_pvec2_init_pos = [
        (
            dot_pos(init_distance)[0] - pvec2_init_pos[0],
            dot_pos(init_distance)[1] - pvec2_init_pos[1],
            dot_pos(init_distance)[2] - pvec2_init_pos[2],
        ),
        (
            dot_pos(init_distance)[0] + pvec2_init_pos[0],
            dot_pos(init_distance)[1] + pvec2_init_pos[1],
            dot_pos(init_distance)[2] + pvec2_init_pos[2],
        ),
    ]
    line_pvec2 = ax.plot(*zip(*line_pvec2_init_pos))[
        0
    ]  # i dont quite know whats the [0] doing, so Ill leave it there
    line_pvec2.set_color("red")
    line_pvec2.set_linewidth(3.0)

    # ==================================================================================#

    # ellipse to be interactive
    def totuple(array):
        try:
            return tuple(totuple(i) for i in array)
        except TypeError:
            return array

    ellipse_init_pos = np.zeros([ellipse_resolution + 1], dtype=object)
    idx_init = index_pos(init_distance)
    for idx in range(ellipse_resolution + 1):
        ellipse_init_pos[idx] = totuple(
            np.array(
                [
                    X_beam_surface[idx_init][idx],
                    Y_beam_surface[idx_init][idx],
                    Z_beam_surface[idx_init][idx],
                ]
            )
        )

    ellipse_int = ax.plot(*zip(*ellipse_init_pos))[
        0
    ]  # i dont quite know whats the [0] doing, so Ill leave it there
    ellipse_int.set_color("blue")
    ellipse_int.set_linewidth(3.0)

    # ==================================================================================#

    # Plotting the cross-section of the beam

    ax2 = plt.subplot2grid((4, 8), (0, 4), colspan=2, rowspan=2)

    def pvec1_2d_pos(idx):
        return np.array([width1[idx] * eigvec1_x[idx], width1[idx] * eigvec1_y[idx]])

    def pvec2_2d_pos(idx):
        return np.array([width2[idx] * eigvec2_x[idx], width2[idx] * eigvec2_y[idx]])

    window_2d_plot = np.max(np.array([np.max(width1), np.max(width2)]))

    ax2.set_xlim(-window_2d_plot - window_size, window_2d_plot + window_size)
    ax2.set_ylim(-window_2d_plot - window_size, window_2d_plot + window_size)

    ax2.set_xlabel("x/m")
    ax2.set_ylabel("y/m")

    pvec1_2d = pvec1_2d_pos(idx_init)
    (line_pvec1_2d,) = ax2.plot(
        [-pvec1_2d[0], pvec1_2d[0]],
        [-pvec1_2d[1], pvec1_2d[1]],
        color="green",
        linewidth=3.0,
    )
    pvec2_2d = pvec2_2d_pos(idx_init)
    (line_pvec2_2d,) = ax2.plot(
        [-pvec2_2d[0], pvec2_2d[0]],
        [-pvec2_2d[1], pvec2_2d[1]],
        color="red",
        linewidth=3.0,
    )

    xline_ax2 = ax2.axvline(x=0, color=colory, lw=0.5)
    yline_ax2 = ax2.axhline(y=0, color=colory, lw=0.5)

    ellipse_init_pos_x = np.zeros(ellipse_resolution + 1)
    ellipse_init_pos_y = np.zeros(ellipse_resolution + 1)

    for idx in range(ellipse_resolution + 1):

        ellipse_init_pos_x[idx] = (
            cos_theta_array[idx] * pvec1_2d[0] + sin_theta_array[idx] * pvec2_2d[0]
        )
        ellipse_init_pos_y[idx] = (
            cos_theta_array[idx] * pvec1_2d[1] + sin_theta_array[idx] * pvec2_2d[1]
        )

    (ellipse_int_2d,) = ax2.plot(
        ellipse_init_pos_x, ellipse_init_pos_y, color="blue", linewidth=3.0
    )

    # ==================================================================================#
    # Plot for the widths

    # 2D width plot
    ax3 = plt.subplot2grid((4, 8), (2, 4), colspan=2, rowspan=2)

    ax3.set_xlabel("distance/m")
    ax3.set_ylabel("width/m")
    ax3.set_xlim(
        min(distance_along_line) - window_size, max(distance_along_line) + window_size
    )
    if include_width1:
        ax3.plot(distance_along_line, width1, lw=2, color="green", label="width1")

    if include_width2:
        ax3.plot(distance_along_line, width2, lw=2, color="red", label="width2")

    lambda_array = (2 * np.pi) / K_magnitude_array

    ax3.plot(
        distance_along_line,
        lambda_array,
        lw=2,
        dashes=[4, 2],
        color="blue",
        label="wavelength",
    )  # plot how the wavelength changes

    line_ax3_cutoff = ax3.axvline(x=init_distance, color="orange", lw=1.5)
    line_ax3 = ax3.axvline(x=init_distance, color="black", lw=1.5)
    ax3.legend(
        fontsize=10,
        loc="upper left",
        # bbox_to_anchor=(0.0, 0.3)
    )

    # ==================================================================================#
    # Plot for the curvature

    ax4 = plt.subplot2grid((4, 8), (2, 6), colspan=2, rowspan=2)

    ax4.set_xlabel("distance/m")
    ax4.set_ylabel("curvature/(1/m)")
    ax4.set_xlim(
        min(distance_along_line) - window_size, max(distance_along_line) + window_size
    )

    ax4.plot(distance_along_line, curv1, lw=2, color="blue", label="curv1")
    ax4.plot(distance_along_line, curv2, lw=2, color="maroon", label="curv2")

    line_ax4_cutoff = ax4.axvline(x=init_distance, color="orange", lw=1.5)
    line_ax4 = ax4.axvline(x=init_distance, color="black", lw=1.5)
    ax4.legend(fontsize=10, loc="upper left", bbox_to_anchor=(0.0, 1.0))

    # ==================================================================================#
    # Plot for the localisation

    ax5 = plt.subplot2grid((4, 8), (0, 6), colspan=2, rowspan=2)
    line_ax5 = ax5.axvline(x=init_distance, color="black", lw=1.5)

    ax5.set_xlabel("distance/m")
    ax5.set_ylabel("localisation")
    # ax5.set_xlim(min(distance_along_line)-window_size, max(distance_along_line)+window_size)

    ##labelling localisations and multiplying localisation terms together
    resultant_loc = 1
    name = "loc"
    if include_p:
        name += "_p"
        resultant_loc *= loc_p
    if include_s:
        name += "_s"
        resultant_loc *= loc_s
    if include_m:
        name += "_m"
        resultant_loc *= loc_m
    if include_b:
        name += "_b"
        resultant_loc *= loc_b
    if include_r:
        name += "_r"
        resultant_loc = resultant_loc * loc_r

    # ax5.plot(distance_along_line, resultant_loc, lw=2, color="red", label=name)

    line_ax5_cutoff = ax5.axvline(x=init_distance, color="orange", lw=1.5)
    line_ax5 = ax5.axvline(x=init_distance, color="black", lw=1.5)
    ax5.legend(
        fontsize=10,
        loc="upper left",
        # bbox_to_anchor=(0.0, 0.3)
    )

    # ==================================================================================#
    # Setting dimensions of slider
    ax_slider = plt.axes(
        [0.08, 0.01, 0.35, 0.03]
    )  # 1st 2 arguments are pos, next 2 are height and width in some order, quantity are ratios wrt to figure proportion

    distance_slider = Slider(
        ax_slider,
        label="Distance[m]",
        valmin=0.0,
        valmax=distance_along_line[out_index],
        valinit=init_distance,
    )

    # update function for the slider
    def update(val):
        pos = dot_pos(val)
        idx = index_pos(val)
        pvec1a = pos - pvec1[idx]
        pvec1b = pos + pvec1[idx]
        pvec2a = pos - pvec2[idx]
        pvec2b = pos + pvec2[idx]

        dot.set_xdata(pos[0])
        dot.set_ydata(pos[1])
        dot.set_3d_properties(pos[2])

        set_data_pvec1_array = np.array(
            [[pvec1a[0], pvec1b[0]], [pvec1a[1], pvec1b[1]]]
        )
        line_pvec1.set_data(set_data_pvec1_array)
        pvec1_z = (pvec1a[2], pvec1b[2])
        line_pvec1.set_3d_properties(pvec1_z)

        set_data_pvec2_array = np.array(
            [[pvec2a[0], pvec2b[0]], [pvec2a[1], pvec2b[1]]]
        )
        line_pvec2.set_data(set_data_pvec2_array)
        pvec2_z = (pvec2a[2], pvec2b[2])
        line_pvec2.set_3d_properties(pvec2_z)

        # Here is the updating for the ellipse
        set_data_ellipse_array = np.zeros([2, ellipse_resolution + 1])
        set_data_ellipse_array[0] = X_beam_surface[idx]
        set_data_ellipse_array[1] = Y_beam_surface[idx]
        ellipse_int.set_data(set_data_ellipse_array)
        ellipse_z = totuple(Z_beam_surface[idx])
        ellipse_int.set_3d_properties(ellipse_z)

        # Updating for 2Dline
        line_pvec1_2d.set_xdata([-pvec1_2d_pos(idx)[0], pvec1_2d_pos(idx)[0]])
        line_pvec1_2d.set_ydata([-pvec1_2d_pos(idx)[1], pvec1_2d_pos(idx)[1]])

        line_pvec2_2d.set_xdata([-pvec2_2d_pos(idx)[0], pvec2_2d_pos(idx)[0]])
        line_pvec2_2d.set_ydata([-pvec2_2d_pos(idx)[1], pvec2_2d_pos(idx)[1]])

        ellipse_2d_x = np.zeros(ellipse_resolution + 1)
        ellipse_2d_y = np.zeros(ellipse_resolution + 1)

        for i in range(ellipse_resolution + 1):

            ellipse_2d_x[i] = (
                cos_theta_array[i] * pvec1_2d_pos(idx)[0]
                + sin_theta_array[i] * pvec2_2d_pos(idx)[0]
            )
            ellipse_2d_y[i] = (
                cos_theta_array[i] * pvec1_2d_pos(idx)[1]
                + sin_theta_array[i] * pvec2_2d_pos(idx)[1]
            )

        ellipse_int_2d.set_xdata(ellipse_2d_x)
        ellipse_int_2d.set_ydata(ellipse_2d_y)

        line_ax3.set_xdata(val)
        line_ax4.set_xdata(val)
        line_ax5.set_xdata(val)

    distance_slider.on_changed(update)
    # keep the slider updated

    return ax, distance_slider
    # must keep the slider globally in order for it to respond. Store it in any variable should be sufficient

# %%
import h5py
import xarray as xr
import datatree
import matplotlib.pyplot as plt

def h5_to_datatree(h5_filename):
    with h5py.File(h5_filename, 'r') as h5_file:
        def recursive_convert(group):
            data = {}
            for key, value in group.items():
                if isinstance(value, h5py.Group):
                    data[key] = recursive_convert(value)  # Recursive for sub-groups
                else:
                    data[key] = value[()]  # Read data from dataset
            return data
        
        data_tree_dict = recursive_convert(h5_file)
        data_tree = DataTree(data_tree_dict)
        
    return data_tree

def read_h5_and_convert_into_dt():
    h5file_path = r"C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\DIII-D shot 189998\tgt\cart\scotty_output.h5"
    dt = datatree.open_datatree(h5file_path, engine="h5netcdf")
    plot_3D_beam_profile_3D_plotting(dt)
    plt.show()

read_h5_and_convert_into_dt()
# Out:
# C:\Users\eduar\AppData\Local\Temp\ipykernel_3276\3665484557.py:343: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   (dot,) = ax.plot(
# C:\Users\eduar\AppData\Local\Temp\ipykernel_3276\3665484557.py:352: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   (dot_cutoff,) = ax.plot(
# C:\Users\eduar\AppData\Local\Temp\ipykernel_3276\3665484557.py:569: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax5.legend(
# C:\Users\eduar\AppData\Local\Temp\ipykernel_3276\3665484557.py:581: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   distance_slider = Slider(
# ...
