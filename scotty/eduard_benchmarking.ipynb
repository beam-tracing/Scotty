# %%
from copy import deepcopy
import numpy as np
from scotty.benchmarking_3D import benchmark_me_up_3D, benchmark_plots
from scotty.fun_general import cylindrical_to_cartesian

def get_launch_stuff(
        DBS_system = "BEST",
        mode_to_try = "O",
        launch_setting = 1):

    if DBS_system == "DIII-D":
        launch_position_cylindrical = np.array([3.01346, 0, -0.09017])
        launch_position_cartesian = launch_position_cylindrical
        poloidal_launch_angle_Torbeam = -7.0
        toroidal_launch_angle_Torbeam = 0 + np.rad2deg(np.arctan2(launch_position_cartesian[1], launch_position_cartesian[0]))
        mode_flag = mode_to_try
        launch_freq_GHz = 72.5
        launch_beam_width = 0.1265
        launch_beam_curvature = -0.95
        Psi_BC_flag = "discontinuous"
        poloidal_flux_enter = 0.95
        poloidal_flux_zero_density = 1.0
        file_dir = r"C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\DIII-D shot 189998\cyl scotty"
        file_suffix = "_189998_3000ms_quinn"

    elif DBS_system == "MAST-U":
        launch_position_cylindrical = np.array([2.278, 0, 0])
        launch_position_cartesian = launch_position_cylindrical
        poloidal_launch_angle_Torbeam = -8.2
        mode_flag = mode_to_try
        Psi_BC_flag = "discontinuous"
        file_dir = r"C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\MAST-U\cyl scotty"
        file_suffix = "_51353_410ms_1.0"

        if launch_setting == 1:
            poloidal_flux_enter = 1.09**2
            toroidal_launch_angle_Torbeam = -10.1 + np.rad2deg(np.arctan2(launch_position_cartesian[1], launch_position_cartesian[0])) # 7.10 + np.rad2deg(np.arctan2(launch_position_cartesian[1], launch_position_cartesian[0]))
            launch_freq_GHz = 32.5
            launch_beam_width = 0.07596928872724663
            launch_beam_curvature = -0.7497156475519201
        elif launch_setting == 2:
            poloidal_flux_enter = 1.09**2
            toroidal_launch_angle_Torbeam = -10.1 + np.rad2deg(np.arctan2(launch_position_cartesian[1], launch_position_cartesian[0])) # 7.10 + np.rad2deg(np.arctan2(launch_position_cartesian[1], launch_position_cartesian[0]))
            launch_freq_GHz = 50.1
            launch_beam_width = 0.04952158283198232
            launch_beam_curvature = -0.8079274424969226
        
        poloidal_flux_zero_density = poloidal_flux_enter + 0.01

    return {
        "poloidal_launch_angle_Torbeam": poloidal_launch_angle_Torbeam,
        "toroidal_launch_angle_Torbeam": toroidal_launch_angle_Torbeam,
        "launch_freq_GHz": launch_freq_GHz,
        "launch_beam_width": launch_beam_width,
        "launch_beam_curvature": launch_beam_curvature,
        "launch_position": launch_position_cylindrical,
        "mode_flag_cyl": 1 if mode_flag in [1, "O"] else -1,
        "mode_flag_cart": mode_flag,
        "vacuumLaunch_flag": True,
        "vacuum_propagation_flag": True,
        "Psi_BC_flag": Psi_BC_flag,
        "poloidal_flux_enter": poloidal_flux_enter,
        "poloidal_flux_zero_density": poloidal_flux_zero_density,
        "ne_data_path": file_dir,
        "magnetic_data_path": file_dir,
        "input_filename_suffix": file_suffix,
        "output_path": file_dir,
    }

# cyl scotty kwargs

kwargs_dict_cyl = get_launch_stuff(
    DBS_system = "DIII-D",
    mode_to_try = "O",
    launch_setting = 1)

kwargs_dict_cart = deepcopy(kwargs_dict_cyl)
kwargs_dict_cyl["mode_flag"] = kwargs_dict_cyl.pop("mode_flag_cyl")
kwargs_dict_cyl.pop("mode_flag_cart")
kwargs_dict_cyl["delta_R"] = -1e-3
kwargs_dict_cyl["delta_Z"] = 1e-3
kwargs_dict_cyl["delta_K_R"]    = -1e-1
kwargs_dict_cyl["delta_K_zeta"] = 1e-1
kwargs_dict_cyl["delta_K_Z"]    = 1e-1
kwargs_dict_cyl["interp_smoothing"] = 0
kwargs_dict_cyl["interp_order"] = 5
kwargs_dict_cyl["len_tau"] = 1002
kwargs_dict_cyl["rtol"] = 1e-4
kwargs_dict_cyl["atol"] = 1e-7
kwargs_dict_cyl["find_B_method"] = "omfit"

# cart scotty kwargs

kwargs_dict_cart["mode_flag"] = kwargs_dict_cart.pop("mode_flag_cart")
kwargs_dict_cart.pop("mode_flag_cyl")
kwargs_dict_cart["launch_position_cartesian"] = kwargs_dict_cart.pop("launch_position")
kwargs_dict_cart["auto_delta_sign"] = True
kwargs_dict_cart["delta_X"] = -1e-3
kwargs_dict_cart["delta_Y"] = 1e-3
kwargs_dict_cart["delta_Z"] = 1e-3
kwargs_dict_cart["delta_K_X"] = -1e-1
kwargs_dict_cart["delta_K_Y"] = 1e-1
kwargs_dict_cart["delta_K_Z"] = 1e-1
kwargs_dict_cart["interp_smoothing"] = 0
kwargs_dict_cart["interp_order"] = 5
kwargs_dict_cart["len_tau"] = 1002
kwargs_dict_cart["rtol"] = 1e-4
kwargs_dict_cart["atol"] = 1e-7
kwargs_dict_cart["further_analysis_flag"] = True
kwargs_dict_cart["figure_flag"] = True
kwargs_dict_cart["return_dt_field"] = True
kwargs_dict_cart["console_log_level"] = "debug"
kwargs_dict_cart["file_log_level"] = "debug"
kwargs_dict_cart["create_magnetic_geometry_3D"] = {
    "pad": 35,
    "Y_spacing": 0.02,
}

# benchmarking

cyl, cart = benchmark_me_up_3D(kwargs_dict_cyl, kwargs_dict_cart)

(dt_cyl_scotty,
 field_cyl_scotty,
 ne_cyl_scotty,
 temeprature_cyl_scotty,
 H_cyl_scotty) = cyl

(dt_cart_scotty,
 field_cart_scotty,
 ne_cart_scotty,
 temeprature_cart_scotty,
 H_cart_scotty) = cart

# printing plots

benchmark_plots(dt_cyl_scotty, dt_cart_scotty)
# Out:
# Beam trace me up, Scotty!
# scotty version 3.0.3.dev46+geba3769.d20250311
# Run ID: b5d7bd96-56db-4908-91f5-059327abfd96
# Using OMFIT JSON Torbeam file for B and poloidal flux
# Beam launched from outside the plasma
# Starting the solvers
# Time taken (ray solver) 0.1335771083831787 s
# Time taken (beam solver) 2.203439950942993s
# Number of beam evolution evaluations: 788
# Time per beam evolution evaluation: 0.0027962435925672504
# Main loop complete
# Analysing data
# The final value of H_Booker is -1.0050681998581363
# polflux:  0.04148838145206279
# theta_m:  -0.0743488781145707
# delta_theta_m:  0.15763741880484902
# mismatch attenuation:  0.6408898065904423
# Making figures
#    DEBUG  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:178   >  Saved and validated launch parameters
#    DEBUG  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:179   >  Initialised logger
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:181   >
#
#     ##################################################
#     #
#     # STARTING ROUTINE
#     #
#     ##################################################
#     #
#     # Beam trace me up, Scotty!
#     # scotty version 3.0.3.dev46+geba3769.d20250311
#     # Run ID: 1bbb1843-ef02-4e01-b35c-7c1e4d505284
#     #
#     ##################################################
#     #
#     # Starting run for:
#     #   - Pol. launch angle = -7.0 deg
#     #   - Tor. launch angle = 0.0 deg
#     #   - Launch frequency = 72.5 GHz
#     #   - Mode flag = O
#     #   - Launch beam width = 0.1265 m
#     #   - Launch beam curvature = -0.95 m^-1
#     #   - Launch position [X,Y,Z] = [ 3.01346,  0.     , -0.09017]
#     #
#     ##################################################
#
#    DEBUG  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:206   >  Setting experimental profiles
#     INFO  >  set_experimental_profiles()  >  checks_3D.py:298   >  Setting experimental profiles
#    DEBUG  >  make_fit()  >  beam_me_up_3D_temp.py:598   >  Making density fit profile
#     INFO  >  _guess_profile_fit_method()  >  profile_fit.py:399   >  Loading `ne(psi)` from input file
#    DEBUG  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:222   >  Making temperature fit profile
#  WARNING  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:223   >  Skipping temperature fit profile -- code not done yet
#    DEBUG  >  create_magnetic_geometry_3D()  >  geometry_3D.py:207   >  Reading and creating field profile
#    DEBUG  >  create_magnetic_geometry_3D()  >  geometry_3D.py:215   >  Two-dimensional (R,Z) field profile passed from `find_B_method`
#    DEBUG  >  create_magnetic_geometry_3D()  >  geometry_3D.py:221   >  Converting the (R,Z)-field into an (X,Y,Z)-field
# Figures have been saved
#    DEBUG  >  __init__()  >  geometry_3D.py:94    >  Interpolating 3D B_X profile took 8.829392433166504 s
#    DEBUG  >  __init__()  >  geometry_3D.py:99    >  Interpolating 3D B_Y profile took 6.479006290435791 s
#    DEBUG  >  __init__()  >  geometry_3D.py:104   >  Interpolating 3D B_Z profile took 10.643244981765747 s
#    DEBUG  >  __init__()  >  geometry_3D.py:109   >  Interpolating 3D poloidal flux profile took 9.254493951797485 s
#    DEBUG  >  create_magnetic_geometry_3D()  >  geometry_3D.py:238   >  Converting the field profile took 35.22491383552551 s
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:237   >
#
#     ##################################################
#     #
#     # LAUNCH ROUTINE
#     #
#     ##################################################
#
#     INFO  >  find_plasma_entry_position()  >  launch_3D.py:23    >  Finding plasma entry position
#    DEBUG  >  _find_plasma_root()  >  launch_3D.py:92    >  Unable to find any roots with `tau_max` = 0.5 with error: attempt to get argmin of an empty sequence
#    DEBUG  >  _find_plasma_root()  >  launch_3D.py:98    >
#         ##################################################
#         #
#         # Finding plasma entry position. Trying:
#         #   - Launch position [X,Y,Z] = [ 3.01346,  0.     , -0.09017]
#         #   - tau = 0 to 0.5
#         #   - poloidal_flux_enter = 0.95
#         #   - poloidal flux along the ray line =
#         #        [2.74600597 2.74600597 2.74600597 2.74600597 2.74600597 2.74600597]
#         #        [2.74600597 2.74600597 2.74600597 2.74600597 2.74600597 2.74600597]
#         #        [2.74600597 2.74600597 2.74600597 2.74600597 2.74600597 2.74600597]
#         #        [2.74600597 2.74600597 2.74600597 2.74600597 2.74600597 2.74600597]
#         #        [2.74600597 2.74600597 2.74600597 2.74600597 2.74600597 2.74600597]
#         #        [2.74600597 2.74600597 2.74600597 2.74600597 2.74600597]
#         #        [2.74600597 2.74600597 2.74600597 2.74600597 2.74600597]
#         #        [2.74600597 2.74600597 2.74600597 2.74600597 2.74600597]
#         #        [2.74600597 2.74600597 2.74600597 2.68522796 2.62281438]
#         #   - (Cubic) spline roots = None
#         #   - Selected root = None
#         #   - Position of selected root [X,Y,Z] = None
#         #   - Poloidal flux position of selected root = None
#         #
#         ##################################################
#
#     INFO  >  find_plasma_entry_position()  >  launch_3D.py:123   >  No root found for `tau_max` = 0.5
#    DEBUG  >  _find_plasma_root()  >  launch_3D.py:98    >
#         ##################################################
#         #
#         # Finding plasma entry position. Trying:
#         #   - Launch position [X,Y,Z] = [ 3.01346,  0.     , -0.09017]
#         #   - tau = 0 to 1.0
#         #   - poloidal_flux_enter = 0.95
#         #   - poloidal flux along the ray line =
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.65390833 2.59132913 2.52720679 2.46157801 2.39446115]
#         #        [2.3258721  2.25583842 2.18439156 2.11155629 2.03735427 1.96181052]
#         #        [1.884955   1.80681187 1.72737922 1.64670066 1.56482237 1.48164304]
#         #        [1.39741648 1.31190393 1.22491052 1.13795381 1.04776805 0.96177368]
#         #        [0.89775857 0.84561486 0.79576035 0.7507827  0.70889521 0.66952215]
#         #        [0.63277109 0.59807765 0.565335   0.53437249 0.50501881 0.47717987]
#         #        [0.45073556 0.42560442 0.40170696 0.37895984 0.35729992 0.33667727]
#         #        [0.3170327  0.29830446 0.280447   0.26342685 0.24720826]
#         #        [0.23174735 0.21699879 0.20293075 0.18952163 0.17674502]
#         #   - (Cubic) spline roots = [0.71878915]
#         #   - Selected root = 0.7187891457101995
#         #   - Position of selected root [X,Y,Z] = [ 2.3000286e+00,  8.7370148e-17, -2.5716388e-03]
#         #   - Poloidal flux position of selected root = 0.9499288672452298
#         #
#         ##################################################
#
#    DEBUG  >  _find_plasma_root()  >  launch_3D.py:98    >
#         ##################################################
#         #
#         # Finding plasma entry position. Trying:
#         #   - Launch position [X,Y,Z] = [ 3.01346,  0.     , -0.09017]
#         #   - tau = 0 to 1.0
#         #   - poloidal_flux_enter = 0.95
#         #   - poloidal flux along the ray line =
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.71490195 2.71490195 2.71490195 2.71490195 2.71490195]
#         #        [2.71490195 2.65390833 2.59132913 2.52720679 2.46157801 2.39446115]
#         #        [2.3258721  2.25583842 2.18439156 2.11155629 2.03735427 1.96181052]
#         #        [1.884955   1.80681187 1.72737922 1.64670066 1.56482237 1.48164304]
#         #        [1.39741648 1.31190393 1.22491052 1.13795381 1.04776805 0.96177368]
#         #        [0.89775857 0.84561486 0.79576035 0.7507827  0.70889521 0.66952215]
#         #        [0.63277109 0.59807765 0.565335   0.53437249 0.50501881 0.47717987]
#         #        [0.45073556 0.42560442 0.40170696 0.37895984 0.35729992 0.33667727]
#         #        [0.3170327  0.29830446 0.280447   0.26342685 0.24720826]
#         #        [0.23174735 0.21699879 0.20293075 0.18952163 0.17674502]
#         #   - (Cubic) spline roots = [0.71878915]
#         #   - Selected root = 0.7187891457101995
#         #   - Position of selected root [X,Y,Z] = [ 2.3000286e+00,  8.7370148e-17, -2.5716388e-03]
#         #   - Poloidal flux position of selected root = 0.9499288672452298
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_position()  >  launch_3D.py:152   >  Plasma entry position, `q_initial_cartesian`, is [X,Y,Z] = [ 2.3000385e+00,  8.7368933e-17, -2.5728574e-03]
#     INFO  >  find_auto_delta_signs()  >  launch_3D.py:165   >  Setting delta signs
#    DEBUG  >  find_auto_delta_signs()  >  launch_3D.py:169   >  Switched delta_X from -0.001 to 0.001
#    DEBUG  >  find_auto_delta_signs()  >  launch_3D.py:173   >  Switched delta_Y from 0.001 to -0.001
#    DEBUG  >  find_auto_delta_signs()  >  launch_3D.py:177   >  Switched delta_Z from 0.001 to -0.001
#     INFO  >  initialise_hamiltonians()  >  hamiltonian_3D.py:331   >  Initialising the Hamiltonians with `mode_flag`s = +1 and -1
#    DEBUG  >  __init__()  >  hamiltonian_3D.py:163   >
#         ##################################################
#         #
#         # Creating Hamiltonian with:
#         #   - mode_flag = 1
#         #   - w_launch = 455530934770.52
#         #   - K_launch = 1519.4876409149692
#         #   - (finite difference) spacings = {'X': 0.001, 'Y': -0.001, 'Z': -0.001, 'K_X': -0.1, 'K_Y': 0.1, 'K_Z': 0.1}
#         #   - field type = <class 'scotty.geometry_3D.InterpolatedField_3D_Cartesian'>
#         #   - density fit type = <class 'scotty.profile_fit.SmoothingSplineFit'>
#         #   - temperature fit type = <class 'NoneType'>
#         #
#         ##################################################
#
#    DEBUG  >  __init__()  >  hamiltonian_3D.py:163   >
#         ##################################################
#         #
#         # Creating Hamiltonian with:
#         #   - mode_flag = -1
#         #   - w_launch = 455530934770.52
#         #   - K_launch = 1519.4876409149692
#         #   - (finite difference) spacings = {'X': 0.001, 'Y': -0.001, 'Z': -0.001, 'K_X': -0.1, 'K_Y': 0.1, 'K_Z': 0.1}
#         #   - field type = <class 'scotty.geometry_3D.InterpolatedField_3D_Cartesian'>
#         #   - density fit type = <class 'scotty.profile_fit.SmoothingSplineFit'>
#         #   - temperature fit type = <class 'NoneType'>
#         #
#         ##################################################
#
#     INFO  >  find_plasma_entry_parameters()  >  launch_3D.py:202   >  Finding plasma entry parameters
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:217   >
#         ##################################################
#         #
#         # Finding plasma entry parameters with:
#         #   - vacuumLaunch_flag = True
#         #   - vacuum_propagation_flag = True
#         #   - Psi_BC_flag = discontinuous
#         #   - mode_flag (at launch, from user) = O
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:366   >  `vacuumLaunch_flag` and `vacuum_propagation_flag` are True. Launching from outside the plasma
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:387   >  `Psi_BC_flag` is discontinuous. Applying boundary conditions to find K and Psi
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:399   >
#         ##################################################
#         #
#         # Calculated values at [X,Y,Z] = [ 2.3000385e+00,  8.7368933e-17, -2.5728574e-03]:
#         #   - poloidal flux = 0.9499999999999141
#         #   - n_e = 0.588955707262657 (e19)
#         #   - T_e = None
#         #   - |B| = 1.3618272837713903
#         #   - b_hat = [ 0.0125875, -0.9832737, -0.1816987]
#         #   - epsilon_11 = 0.8751540131816642
#         #   - epsilon_12 = 0.0656447714399197
#         #   - epsilon_bb = 0.9096704291852454
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:426   >  `mode_flag` is O. Applying boundary conditions for Hamiltonian with `mode_flag` = 1
#    DEBUG  >  apply_discontinuous_BC_3D()  >  boundary_conditions_3D.py:639   >  Applying discontinuous boundary conditions
#    DEBUG  >  find_K_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:280   >
#         Finding K at the plasma entry point with discontinuous boundary conditions
#         ##################################################
#         #
#         # Calculated at [X,Y,Z] = [ 2.3000385e+00,  8.7368933e-17, -2.5728574e-03]:
#         #   - B_X = 0.01714193970886985
#         #   - B_Y = -1.3390489286207377
#         #   - B_Z = -0.24744225889454377
#         #   - |B| = 1.3618272837713903
#         #
#         #   - w_pe / w_launch = 0.30054878275373964
#         #   - w_ce / w_launch = 0.5258060199839649
#         #   - w_L  / w_launch = 0.13640584725713872
#         #   - w_R  / w_launch = 0.6622118672411037
#         #   - w_UH / w_launch = 0.60564142978014
#         #
#         #   - d(polflux)/dX = 7.2240858084804405
#         #   - d(polflux)/dY = 2.220446049250313e-13
#         #   - d(polflux)/dZ = 0.45028028030802414
#         #
#         ##################################################
#
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:454   >
#         Finding Psi at the plasma entry point with discontinuous boundary conditions
#         ##################################################
#         #
#         # Derivatives at [X,Y,Z] = [ 2.3000385e+00,  8.7368933e-17, -2.5728574e-03] with K_plasma = [-1.4368637e+03,  2.1914615e-12,  1.8962299e+02]:
#         #   - dH/dX = -17.073045633618168
#         #   - dH/dY = -0.0025060457453096596
#         #   - dH/dZ = -1.0494561579705852
#         #   - dH/dKx = -0.0012447567210266408
#         #   - dH/dKy = -4.011351080190906e-06
#         #   - dH/dKz = 0.00016353613311259618
#         #
#         #   - d(polflux)/dX = 7.2240858084804405
#         #   - d(polflux)/dY = 2.220446049250313e-13
#         #   - d(polflux)/dZ = 0.45028028030802414
#         #
#         #   - d2(polflux)/dX2 = 266.70413775464755
#         #   - d2(polflux)/dY2 = 3.1637332744693936
#         #   - d2(polflux)/dZ2 = 10.418986479354686
#         #   - d2(polflux)/dXdY = -2.7755575615628914e-11
#         #   - d2(polflux)/dXdZ = 10.289955714143373
#         #   - d2(polflux)/dYdZ = -1.1102230246251565e-10
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:536   >
#         #
#         #   - interface matrix =
#         #        [ 4.9303807e-26, -3.2081386e-12,  0.0000000e+00,  5.2187416e+01,
#   0.0000000e+00,  0.0000000e+00]
#         #        [ 0.2027523,  0.       , -6.5057268,  0.       ,  0.       , 52.1874158]
#         #        [ 0.2027523,  0.4055047, -6.5057268,  0.2027523, -6.5057268, 52.1874158]
#         #        [-1.2447567e-03, -4.0113511e-06,  1.6353613e-04,  0.0000000e+00,
#   0.0000000e+00,  0.0000000e+00]
#         #        [ 0.0000000e+00, -1.2447567e-03,  0.0000000e+00, -4.0113511e-06,
#   1.6353613e-04,  0.0000000e+00]
#         #        [ 0.0000000e+00,  0.0000000e+00, -1.2447567e-03,  0.0000000e+00,
#  -4.0113511e-06,  1.6353613e-04]
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:554   >
#         #
#         #   - interface matrix inverse =
#         #        [-3.1176096e-07,  2.0391293e-04,  1.3231581e-04, -8.0331507e+02,
#   2.6318664e+00, -1.0729683e+02]
#         #        [ 1.6844776e-05,  2.0361253e-02, -2.0361253e-02,  2.0579079e-13,
#  -8.1000292e+02, -3.3072768e-12]
#         #        [-1.9597886e-06,  2.0515229e-03,  5.0768514e-04,  4.1685687e-01,
#   1.6404533e-01, -8.1669078e+02]
#         #        [ 1.9161708e-02,  1.2516757e-15, -1.2516757e-15,  7.7157865e-25,
#  -4.9793644e-11, -1.0194144e-25]
#         #        [ 5.9822855e-04,  1.5497985e-01, -1.5497985e-01,  1.5663784e-12,
#  -5.0487820e+01, -2.5173367e-11]
#         #        [-2.4309766e-07,  1.9416660e-02,  6.2774395e-05,  3.1729097e+00,
#   1.0225014e-02, -1.0139250e+02]
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:575   >
#         #
#         #   - eta_XY  = -1.5818666372346968
#         #   - eta_XZ  = -5.066515758683586
#         #   - eta_XYZ = -5.072637654447172
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:590   >
#         #
#         #   - RHS vector =
#         #        -224213.64532004358 + 62664.78569769408j
#         #        -213857.01664694195 + 60792.767484839256j
#         #        -214728.1047919395 + 61036.225245193724j
#         #        17.073045633618168
#         #        0.0025060457453096596
#         #        1.0494561579705852
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:608   >
#         #
#         #   - Psi_3D_plasma_labframe_cartesian
#         #        Psi_XX_p = -13899.581755491638 + 20.45295232147194j
#         #        Psi_XY_p = 11.929712774367383 + -3.901530685781381j
#         #        Psi_XZ_p = -1397.2711557617174 + 155.5821271628345j
#         #        Psi_YY_p = -4296.316305745994 + 1200.7642987329546j
#         #        Psi_YZ_p = 0.7435839698831431 + -0.2431840342705982j
#         #        Psi_ZZ_p = -4218.049603809429 + 1184.2087694936713j
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:455   >
#         ##################################################
#         #
#         # Calculated values for Hamiltonian with `+1`:
#         #   - K_initial_cartesian = [-1.4368637e+03,  2.1914615e-12,  1.8962299e+02]
#         #
#         #   - Psi_3D_initial_labframe_cartesian =
#         #        [[-1.3899582e+04 +20.4529523j,  1.1929713e+01  -3.9015307j,
#  -1.3972712e+03+155.5821272j],
#         #         [ 1.1929713e+01-3.9015307e+00j, -4.2963163e+03+1.2007643e+03j,
#   7.4358397e-01-2.4318403e-01j],
#         #         [-1.3972712e+03+1.5558213e+02j,  7.4358397e-01-2.4318403e-01j,
#  -4.2180496e+03+1.1842088e+03j]]
#         #
#         #   - theta_m (in radians) = -0.03625986776232022
#         #   - theta_m (in degrees) = -2.077537388483421
#         #
#         #   - H[0] = -0.0394840330848771
#         #   - e_hat[0] = [-0.0737009+0.0000000e+00j,  0.       +9.9548153e-01j,
#  -0.0598724-1.3877788e-17j]
#         #
#         #   - H[1] = 1.3154951285755575e-15
#         #   - e_hat[1] = [-3.2929461e-02+0.0000000e+00j, -5.5511151e-17-6.2432050e-02j,
#  -9.9750583e-01+2.7755576e-17j]
#         #
#         #   - H[2] = 0.8799064725354785
#         #   - e_hat[2] = [-0.9967366+0.0000000e+00j,  0.       -7.1545507e-02j,
#   0.037382 +2.7376105e-18j]
#         #
#         #   - mode_index = 1
#         #   - selected H = 1.3154951285755575e-15
#         #   - selected e_hat = [-3.2929461e-02+0.0000000e+00j, -5.5511151e-17-6.2432050e-02j,
#  -9.9750583e-01+2.7755576e-17j]
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:493   >  `mode_flag` is O. Applying boundary conditions for Hamiltonian with `mode_flag` = -1
#    DEBUG  >  apply_discontinuous_BC_3D()  >  boundary_conditions_3D.py:639   >  Applying discontinuous boundary conditions
#    DEBUG  >  find_K_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:280   >
#         Finding K at the plasma entry point with discontinuous boundary conditions
#         ##################################################
#         #
#         # Calculated at [X,Y,Z] = [ 2.3000385e+00,  8.7368933e-17, -2.5728574e-03]:
#         #   - B_X = 0.01714193970886985
#         #   - B_Y = -1.3390489286207377
#         #   - B_Z = -0.24744225889454377
#         #   - |B| = 1.3618272837713903
#         #
#         #   - w_pe / w_launch = 0.30054878275373964
#         #   - w_ce / w_launch = 0.5258060199839649
#         #   - w_L  / w_launch = 0.13640584725713872
#         #   - w_R  / w_launch = 0.6622118672411037
#         #   - w_UH / w_launch = 0.60564142978014
#         #
#         #   - d(polflux)/dX = 7.2240858084804405
#         #   - d(polflux)/dY = 2.220446049250313e-13
#         #   - d(polflux)/dZ = 0.45028028030802414
#         #
#         ##################################################
#
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:454   >
#         Finding Psi at the plasma entry point with discontinuous boundary conditions
#         ##################################################
#         #
#         # Derivatives at [X,Y,Z] = [ 2.3000385e+00,  8.7368933e-17, -2.5728574e-03] with K_plasma = [-1.4043281e+03,  3.1914994e-12,  1.9165095e+02]:
#         #   - dH/dX = -25.643533957509955
#         #   - dH/dY = 0.0035236473746591557
#         #   - dH/dZ = -1.5704683163794697
#         #   - dH/dKx = -0.001216336450078348
#         #   - dH/dKy = 5.770401423355054e-06
#         #   - dH/dKz = 0.00016705164469554834
#         #
#         #   - d(polflux)/dX = 7.2240858084804405
#         #   - d(polflux)/dY = 2.220446049250313e-13
#         #   - d(polflux)/dZ = 0.45028028030802414
#         #
#         #   - d2(polflux)/dX2 = 266.70413775464755
#         #   - d2(polflux)/dY2 = 3.1637332744693936
#         #   - d2(polflux)/dZ2 = 10.418986479354686
#         #   - d2(polflux)/dXdY = -2.7755575615628914e-11
#         #   - d2(polflux)/dXdZ = 10.289955714143373
#         #   - d2(polflux)/dYdZ = -1.1102230246251565e-10
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:536   >
#         #
#         #   - interface matrix =
#         #        [ 4.9303807e-26, -3.2081386e-12,  0.0000000e+00,  5.2187416e+01,
#   0.0000000e+00,  0.0000000e+00]
#         #        [ 0.2027523,  0.       , -6.5057268,  0.       ,  0.       , 52.1874158]
#         #        [ 0.2027523,  0.4055047, -6.5057268,  0.2027523, -6.5057268, 52.1874158]
#         #        [-1.2163365e-03,  5.7704014e-06,  1.6705164e-04,  0.0000000e+00,
#   0.0000000e+00,  0.0000000e+00]
#         #        [ 0.0000000e+00, -1.2163365e-03,  0.0000000e+00,  5.7704014e-06,
#   1.6705164e-04,  0.0000000e+00]
#         #        [ 0.0000000e+00,  0.0000000e+00, -1.2163365e-03,  0.0000000e+00,
#   5.7704014e-06,  1.6705164e-04]
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:554   >
#         #
#         #   - interface matrix inverse =
#         #        [ 1.2304217e-06,  5.7147691e-04, -2.0377507e-04, -8.2207965e+02,
#  -3.9679493e+00, -1.1487112e+02]
#         #        [ 1.7441431e-04,  2.1292908e-02, -2.1292908e-02,  2.2031809e-13,
#  -8.2923962e+02, -3.5407460e-12]
#         #        [ 2.9342195e-06,  3.4255249e-03, -7.4821421e-04,  4.4628358e-01,
#  -2.4732393e-01, -8.3639958e+02]
#         #        [ 1.9161708e-02,  1.3089477e-15, -1.3089477e-15,  7.9019945e-25,
#  -5.0976189e-11, -1.0913781e-25]
#         #        [ 6.0804993e-04,  1.5503792e-01, -1.5503792e-01,  1.6041801e-12,
#  -5.1686851e+01, -2.5780880e-11]
#         #        [ 3.6100196e-07,  1.9586516e-02, -9.2481325e-05,  3.2494800e+00,
#  -1.5415804e-02, -1.0381999e+02]
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:575   >
#         #
#         #   - eta_XY  = -1.5818666372346968
#         #   - eta_XZ  = -5.066515758683586
#         #   - eta_XYZ = -5.072637654447172
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:590   >
#         #
#         #   - RHS vector =
#         #        -223470.04101231095 + 62664.78569769408j
#         #        -211466.0945361576 + 60792.767484839256j
#         #        -212334.29371827844 + 61036.225245193724j
#         #        25.643533957509955
#         #        -0.0035236473746591557
#         #        1.5704683163794697
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:608   >
#         #
#         #   - Psi_3D_plasma_labframe_cartesian
#         #        Psi_XX_p = -21339.269498677935 + 22.381106092970455j
#         #        Psi_XY_p = -17.567940074273924 + 5.745711772129425j
#         #        Psi_XZ_p = -1868.260430955784 + 162.76283972018993j
#         #        Psi_YY_p = -4282.067577450382 + 1200.7642987329552j
#         #        Psi_YZ_p = -1.0950170308258607 + 0.35813261025759857j
#         #        Psi_ZZ_p = -4202.045580710238 + 1185.0964320752971j
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:522   >
#         ##################################################
#         #
#         # Calculated values for Hamiltonian with `-1`:
#         #   - K_initial_cartesian = [-1.4043281e+03,  3.1914994e-12,  1.9165095e+02]
#         #
#         #   - Psi_3D_initial_labframe_cartesian =
#         #        [[-2.1339269e+04 +22.3811061j, -1.7567940e+01  +5.7457118j,
#  -1.8682604e+03+162.7628397j],
#         #         [-1.7567940e+01+5.7457118e+00j, -4.2820676e+03+1.2007643e+03j,
#  -1.0950170e+00+3.5813261e-01j],
#         #         [-1.8682604e+03+1.6276284e+02j, -1.0950170e+00+3.5813261e-01j,
#  -4.2020456e+03+1.1850964e+03j]]
#         #
#         #   - theta_m (in radians) = -0.03704930675110055
#         #   - theta_m (in degrees) = -2.122768910723609
#         #
#         #   - H[0] = 4.847965505528403e-15
#         #   - e_hat[0] = [-7.6989751e-02+0.0000000e+00j, -1.1102230e-16+9.9517694e-01j,
#  -6.0790142e-02+6.9388939e-18j]
#         #
#         #   - H[1] = 0.03970672100894984
#         #   - e_hat[1] = [-3.3507010e-02+0.0000000e+00j,  5.5511151e-17-6.3519233e-02j,
#  -9.9741796e-01+5.5511151e-17j]
#         #
#         #   - H[2] = 0.8801206449912703
#         #   - e_hat[2] = [-0.9964687+0.0000000e+00j,  0.       -7.4754065e-02j,
#   0.0382357-1.0570971e-18j]
#         #
#         #   - mode_index = 0
#         #   - selected H = 4.847965505528403e-15
#         #   - selected e_hat = [-7.6989751e-02+0.0000000e+00j, -1.1102230e-16+9.9517694e-01j,
#  -6.0790142e-02+6.9388939e-18j]
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:612   >
#         ##################################################
#         #
#         # Calculated plasma entry parameters for:
#         #   - O-mode (selected):
#         #        - K = [-1.4368637e+03,  2.1914615e-12,  1.8962299e+02]
#         #
#         #        - Psi_3D =
#         #             [[-1.3899582e+04 +20.4529523j,  1.1929713e+01  -3.9015307j,
#  -1.3972712e+03+155.5821272j],
#         #              [ 1.1929713e+01-3.9015307e+00j, -4.2963163e+03+1.2007643e+03j,
#   7.4358397e-01-2.4318403e-01j],
#         #              [-1.3972712e+03+1.5558213e+02j,  7.4358397e-01-2.4318403e-01j,
#  -4.2180496e+03+1.1842088e+03j]]
#         #
#         #        - mode_flag = 1
#         #
#         #        - mode_index = 1
#         #
#         #        - H = 1.3154951285755575e-15
#         #
#         #        - e_hat = [-3.2929461e-02+0.0000000e+00j, -5.5511151e-17-6.2432050e-02j,
#  -9.9750583e-01+2.7755576e-17j]
#         #
#         #   - X-mode (not selected):
#         #        - K = [-1.4043281e+03,  3.1914994e-12,  1.9165095e+02]
#         #
#         #        - Psi_3D =
#         #             [[-2.1339269e+04 +22.3811061j, -1.7567940e+01  +5.7457118j,
#  -1.8682604e+03+162.7628397j],
#         #              [-1.7567940e+01+5.7457118e+00j, -4.2820676e+03+1.2007643e+03j,
#  -1.0950170e+00+3.5813261e-01j],
#         #              [-1.8682604e+03+1.6276284e+02j, -1.0950170e+00+3.5813261e-01j,
#  -4.2020456e+03+1.1850964e+03j]]
#         #
#         #        - mode_flag = -1
#         #
#         #        - mode_index = 0
#         #
#         #        - H = 4.847965505528403e-15
#         #
#         #        - e_hat = [-7.6989751e-02+0.0000000e+00j, -1.1102230e-16+9.9517694e-01j,
#  -6.0790142e-02+6.9388939e-18j]
#         #
#         ##################################################
#
#     INFO  >  assign_hamiltonians()  >  hamiltonian_3D.py:369   >  Assigning the correct Hamiltonian corresponding to `mode_flag` = O
#    DEBUG  >  assign_hamiltonians()  >  hamiltonian_3D.py:374   >
#         ##################################################
#         #
#         # For [X,Y,Z] = [ 2.3000385e+00,  8.7368933e-17, -2.5728574e-03] and K = [-1.4368637e+03,  2.1914615e-12,  1.8962299e+02]:
#         #   - H (mode_flag +1) = 1.1102230246251565e-16
#         #   - H (mode_flag -1) = 0.03969597040199291
#         #   - H tolerance      = 1e-05
#         #
#         ##################################################
#
#    DEBUG  >  assign_hamiltonians()  >  hamiltonian_3D.py:408   >  Hamiltonian with computed `mode_flag` = 1 selected for user-passed `mode_flag` = O
#     INFO  >  check_input_before_ray_tracing()  >  checks_3D.py:326   >  Checking the validity of user-specified arguments
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:328   >
#
#     ##################################################
#     #
#     # RAY TRACING ROUTINE
#     #
#     ##################################################
#
#     INFO  >  propagate_ray()  >  ray_solver_3D.py:394   >  Starting the ray solver
#     INFO  >  propagate_ray()  >  ray_solver_3D.py:411   >
#
#         Ray solver status: 1
#         Ray solver took 1.2732689380645752 s
#         Number of ray evolution evaluations: 176
#         Time per ray evolution evaluation: 0.007234482602639632
#
#     INFO  >  handle_leaving_plasma_events()  >  ray_solver_3D.py:191   >
#
#         Ray has crossed resonance
#
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:355   >
#
#     ##################################################
#     #
#     # BEAM TRACING ROUTINE
#     #
#     ##################################################
#
#     INFO  >  evolve_beam()  >  fun_evolution_3D.py:135   >  Starting the beam solver
#     INFO  >  evolve_beam()  >  fun_evolution_3D.py:151   >
#
#         Beam solver status: 0
#         Beam solver took 19.007922410964966 s
#         Number of beam evolution evaluations: 626
#         Time per beam evolution evaluation: 0.030364093308250743
#
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:390   >
#
#     ##################################################
#     #
#     # DATA SAVING ROUTINE
#     #
#     ##################################################
#
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:517   >
#
#     ##################################################
#     #
#     # DATA ANALYSIS ROUTINE
#     #
#     # Process the data from the main loop to give a
#     # bunch of useful stuff
#     #
#     ##################################################
#
#     INFO  >  beam_tracing_analysis_3D()  >  analysis_3D.py:45    >
#
#         ##################################################
#         #
#         # RAY AND BEAM TRACING ANALYSIS ROUTINE
#         #
#         ##################################################
#
#    DEBUG  >  beam_tracing_analysis_3D()  >  analysis_3D.py:53    >  Performing analysis on ray tracing results
#    DEBUG  >  beam_tracing_analysis_3D()  >  analysis_3D.py:101   >  Performing analysis on beam tracing results
#     INFO  >  analysis_dbs()  >  analysis_dbs_3D.py:28    >
#
#         ##################################################
#         #
#         # DOPPLER BACKSCATTERING ANALYSIS ROUTINE
#         #
#         ##################################################
#
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:36    >  Performing doppler backscattering analysis
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:81    >  Finding the wavenumber resolution and mismatch attenuation
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:97    >  Finding the polarisation piece (loc_p)
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:129   >  Finding the ray piece (loc_r)
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:166   >  Finding the beam piece (loc_b)
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:178   >  Finding the mismatch piece (loc_m)
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:185   >  Finding the spectrum piece (loc_s)
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:192   >  Finding total localisation (loc_p * loc_r * loc_b * loc_m * loc_s)
# Plotting and saving data
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:575   >  Figures saved to
#         C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\DIII-D shot 189998\cyl scotty
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:577   >
#
#     ##################################################
#     #
#     # FINISHED RUN !
#     #
#     ##################################################
#
# c:\Users\eduar\anaconda3\envs\scotty3dtest\lib\site-packages\matplotlib\cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\eduar\anaconda3\envs\scotty3dtest\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# (<Figure size 1500x2000 with 15 Axes>,
#  array([[<Axes: title={'center': 'q_X'}>, <Axes: title={'center': 'q_Y'}>,
#          <Axes: title={'center': 'q_Z'}>],
#         [<Axes: title={'center': 'K_X'}>, <Axes: title={'center': 'K_Y'}>,
#          <Axes: title={'center': 'K_Z'}>],
#         [<Axes: title={'center': 'Principal Width 1'}>,
#          <Axes: title={'center': 'Principal Width 2'}>,
#          <Axes: title={'center': 'Principal Widths'}>],
#         [<Axes: title={'center': 'Principal Curvature 1'}>,
#          <Axes: title={'center': 'Principal Curvature 2'}>,
#          <Axes: title={'center': 'Principal Widths'}>],
#         [<Axes: title={'center': 'H_Cardano'}>, <Axes: >, <Axes: >]],
#        dtype=object))
