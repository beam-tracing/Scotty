# %%
from copy import deepcopy
import numpy as np
from scotty.benchmarking_3D import benchmark_me_up_3D, benchmark_plots
from scotty.fun_general import cylindrical_to_cartesian

def get_launch_stuff(
        DBS_system = "DIII-D",
        mode_to_try = "O",
        launch_setting = 1):

    if DBS_system == "DIII-D":
        launch_position_cylindrical = np.array([3.01346, 0, -0.09017])
        launch_position_cartesian = launch_position_cylindrical
        poloidal_launch_angle_Torbeam = -7.0
        toroidal_launch_angle_Torbeam = 0 + np.rad2deg(np.arctan2(launch_position_cartesian[1], launch_position_cartesian[0]))
        mode_flag = mode_to_try
        launch_freq_GHz = 72.5
        launch_beam_width = 0.1265
        launch_beam_curvature = -0.95
        Psi_BC_flag = "discontinuous"
        poloidal_flux_enter = 0.95
        poloidal_flux_zero_density = 1.0
        file_dir = r"C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\DIII-D shot 189998\cyl scotty"
        file_suffix = "_189998_3000ms_quinn"

    elif DBS_system == "MAST-U":
        launch_position_cylindrical = np.array([2.278, 0, 0])
        launch_position_cartesian = launch_position_cylindrical
        poloidal_launch_angle_Torbeam = -8.2
        mode_flag = mode_to_try
        Psi_BC_flag = "discontinuous"
        file_dir = r"C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\MAST-U\cyl scotty"
        file_suffix = "_51353_410ms_1.0"

        if launch_setting == 1:
            poloidal_flux_enter = 1.09**2
            toroidal_launch_angle_Torbeam = -10.1 + np.rad2deg(np.arctan2(launch_position_cartesian[1], launch_position_cartesian[0])) # 7.10 + np.rad2deg(np.arctan2(launch_position_cartesian[1], launch_position_cartesian[0]))
            launch_freq_GHz = 32.5
            launch_beam_width = 0.07596928872724663
            launch_beam_curvature = -0.7497156475519201
        elif launch_setting == 2:
            poloidal_flux_enter = 1.09**2
            toroidal_launch_angle_Torbeam = -10.1 + np.rad2deg(np.arctan2(launch_position_cartesian[1], launch_position_cartesian[0])) # 7.10 + np.rad2deg(np.arctan2(launch_position_cartesian[1], launch_position_cartesian[0]))
            launch_freq_GHz = 50.1
            launch_beam_width = 0.04952158283198232
            launch_beam_curvature = -0.8079274424969226
        
        poloidal_flux_zero_density = poloidal_flux_enter + 0.01

    return {
        "poloidal_launch_angle_Torbeam": poloidal_launch_angle_Torbeam,
        "toroidal_launch_angle_Torbeam": toroidal_launch_angle_Torbeam,
        "launch_freq_GHz": launch_freq_GHz,
        "launch_beam_width": launch_beam_width,
        "launch_beam_curvature": launch_beam_curvature,
        "launch_position": launch_position_cylindrical,
        "mode_flag_cyl": 1 if mode_flag in [1, "O"] else -1,
        "mode_flag_cart": mode_flag,
        "vacuumLaunch_flag": True,
        "vacuum_propagation_flag": True,
        "Psi_BC_flag": Psi_BC_flag,
        "poloidal_flux_enter": poloidal_flux_enter,
        "poloidal_flux_zero_density": poloidal_flux_zero_density,
        "ne_data_path": file_dir,
        "magnetic_data_path": file_dir,
        "input_filename_suffix": file_suffix,
        "output_path": file_dir,
    }

# cyl scotty kwargs

kwargs_dict_cyl = get_launch_stuff(
    DBS_system = "DIII-D",
    mode_to_try = "O",
    launch_setting = 1)

kwargs_dict_cart = deepcopy(kwargs_dict_cyl)
kwargs_dict_cyl["mode_flag"] = kwargs_dict_cyl.pop("mode_flag_cyl")
kwargs_dict_cyl.pop("mode_flag_cart")
kwargs_dict_cyl["delta_R"] = -1e-3
kwargs_dict_cyl["delta_Z"] = 1e-3
kwargs_dict_cyl["delta_K_R"]    = -1e-1
kwargs_dict_cyl["delta_K_zeta"] = 1e-1
kwargs_dict_cyl["delta_K_Z"]    = 1e-1
kwargs_dict_cyl["interp_smoothing"] = 0
kwargs_dict_cyl["interp_order"] = 5
kwargs_dict_cyl["len_tau"] = 1002
kwargs_dict_cyl["rtol"] = 1e-4
kwargs_dict_cyl["atol"] = 1e-7
kwargs_dict_cyl["find_B_method"] = "omfit"

# cart scotty kwargs

kwargs_dict_cart["mode_flag"] = kwargs_dict_cart.pop("mode_flag_cart")
kwargs_dict_cart.pop("mode_flag_cyl")
kwargs_dict_cart["launch_position_cartesian"] = kwargs_dict_cart.pop("launch_position")
kwargs_dict_cart["auto_delta_sign"] = True
kwargs_dict_cart["delta_X"] = -1e-3
kwargs_dict_cart["delta_Y"] = 1e-3
kwargs_dict_cart["delta_Z"] = 1e-3
kwargs_dict_cart["delta_K_X"] = -1e-1
kwargs_dict_cart["delta_K_Y"] = 1e-1
kwargs_dict_cart["delta_K_Z"] = 1e-1
kwargs_dict_cart["interp_smoothing"] = 0
kwargs_dict_cart["interp_order"] = 5
kwargs_dict_cart["len_tau"] = 1002
kwargs_dict_cart["rtol"] = 1e-4
kwargs_dict_cart["atol"] = 1e-7
kwargs_dict_cart["further_analysis_flag"] = True
kwargs_dict_cart["figure_flag"] = True
kwargs_dict_cart["return_dt_field"] = True
kwargs_dict_cart["console_log_level"] = "debug"
kwargs_dict_cart["file_log_level"] = "debug"
kwargs_dict_cart["create_magnetic_geometry_3D"] = {
    "pad": 35,
    "Y_spacing": 0.02,
}

# benchmarking

cyl, cart = benchmark_me_up_3D(kwargs_dict_cyl, kwargs_dict_cart)

(dt_cyl_scotty,
 field_cyl_scotty,
 ne_cyl_scotty,
 temeprature_cyl_scotty,
 H_cyl_scotty) = cyl

(dt_cart_scotty,
 field_cart_scotty,
 ne_cart_scotty,
 temeprature_cart_scotty,
 H_cart_scotty) = cart

# printing plots

benchmark_plots(dt_cyl_scotty, dt_cart_scotty)
# Out:
#     INFO  >  _guess_profile_fit_method()  >  profile_fit.py:399   >  Loading `ne(psi)` from input file
# Beam trace me up, Scotty!
# scotty version 3.0.3.dev46+geba3769.d20250311
# Run ID: 8ed68bf1-b284-463a-b057-aac33afefa66
# Using OMFIT JSON Torbeam file for B and poloidal flux
# Beam launched from outside the plasma
# Time taken (ray solver) 0.09951114654541016 s
# Time taken (cut-off finder) 0.013994216918945312 s
# Time taken (beam solver) 1.2959849834442139s
# Number of beam evolution evaluations: 494
# Time per beam evolution evaluation: 0.0026234513834903113
# Main loop complete
# Analysing data
# The final value of H_Booker is -1.0294071400851479e-06
# polflux:  0.452624372334507
# theta_m:  -0.17891164576529764
# delta_theta_m:  0.3734300688245716
# mismatch attenuation:  0.6318645102060565
# Making figures
#    DEBUG  >  benchmark_me_up_3D()  >  benchmarking_3D.py:63    >  Creating X-coordinates: [1.8228125  1.83609375 1.849375   1.86265625 1.8759375  1.88921875
#  1.9025     1.91578125 1.9290625  1.94234375 1.955625   1.96890625
#  1.9821875  1.99546875 2.00875    2.02203125 2.0353125  2.04859375
#  2.061875   2.07515625 2.0884375  2.10171875 2.115      2.12828125
#  2.1415625  2.15484375 2.168125   2.18140625 2.1946875  2.20796875
#  2.22125    2.23453125 2.2478125  2.26109375 2.274375   2.28765625
#  2.3009375  2.31421875 2.3275     2.34078125 2.3540625  2.36734375
#  2.380625   2.39390625 2.4071875  2.42046875 2.43375    2.44703125
#  2.4603125  2.47359375 2.486875   2.50015625 2.5134375  2.52671875
#  2.54      ]
#    DEBUG  >  benchmark_me_up_3D()  >  benchmarking_3D.py:68    >  Creating Y-coordinates: [-0.7  -0.68 -0.66 -0.64 -0.62 -0.6  -0.58 -0.56 -0.54 -0.52 -0.5  -0.48
#  -0.46 -0.44 -0.42 -0.4  -0.38 -0.36 -0.34 -0.32 -0.3  -0.28 -0.26 -0.24
#  -0.22 -0.2  -0.18 -0.16 -0.14 -0.12 -0.1  -0.08 -0.06 -0.04 -0.02  0.
#   0.02  0.04  0.06  0.08  0.1   0.12  0.14  0.16  0.18  0.2   0.22  0.24
#   0.26  0.28  0.3   0.32  0.34  0.36  0.38  0.4   0.42  0.44  0.46  0.48
#   0.5   0.52  0.54  0.56  0.58  0.6   0.62  0.64  0.66  0.68  0.7   0.72]
#    DEBUG  >  benchmark_me_up_3D()  >  benchmarking_3D.py:73    >  Creating Z-coordinates: [-0.7   -0.675 -0.65  -0.625 -0.6   -0.575 -0.55  -0.525 -0.5   -0.475
#  -0.45  -0.425 -0.4   -0.375 -0.35  -0.325 -0.3   -0.275 -0.25  -0.225
#  -0.2   -0.175 -0.15  -0.125 -0.1   -0.075 -0.05  -0.025  0.     0.025
#   0.05   0.075  0.1    0.125  0.15   0.175  0.2    0.225  0.25   0.275
#   0.3    0.325  0.35   0.375  0.4    0.425  0.45   0.475  0.5    0.525
#   0.55   0.575  0.6    0.625  0.65   0.675  0.7    0.725  0.75   0.775
#   0.8    0.825  0.85 ]
#    DEBUG  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:178   >  Saved and validated launch parameters
#    DEBUG  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:179   >  Initialised logger
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:181   >
#
#     ##################################################
#     #
#     # STARTING ROUTINE
#     #
#     ##################################################
#     #
#     # Beam trace me up, Scotty!
#     # scotty version 3.0.3.dev46+geba3769.d20250311
#     # Run ID: 709aebbd-99ac-47b9-b973-6388a0f11d52
#     #
#     ##################################################
#     #
#     # Starting run for:
#     #   - Pol. launch angle = -7.0 deg
#     #   - Tor. launch angle = 0.0 deg
#     #   - Launch frequency = 72.5 GHz
#     #   - Mode flag = X
#     #   - Launch beam width = 0.1265 m
#     #   - Launch beam curvature = -0.95 m^-1
#     #   - Launch position [X,Y,Z] = [ 3.01346,  0.     , -0.09017]
#     #
#     ##################################################
#
#    DEBUG  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:206   >  Setting experimental profiles
#     INFO  >  set_experimental_profiles()  >  checks_3D.py:298   >  Setting experimental profiles
#    DEBUG  >  make_fit()  >  beam_me_up_3D_temp.py:598   >  Making density fit profile
#     INFO  >  _guess_profile_fit_method()  >  profile_fit.py:399   >  Loading `ne(psi)` from input file
#    DEBUG  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:222   >  Making temperature fit profile
#  WARNING  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:223   >  Skipping temperature fit profile -- code not done yet
#    DEBUG  >  create_magnetic_geometry_3D()  >  geometry_3D.py:207   >  Reading and creating field profile
#    DEBUG  >  create_magnetic_geometry_3D()  >  geometry_3D.py:215   >  Two-dimensional (R,Z) field profile passed from `find_B_method`
#    DEBUG  >  create_magnetic_geometry_3D()  >  geometry_3D.py:221   >  Converting the (R,Z)-field into an (X,Y,Z)-field
# Figures have been saved
# trace is already an existing log level. Skipping this step
#    DEBUG  >  __init__()  >  geometry_3D.py:94    >  Interpolating 3D B_X profile took 3.7414629459381104 s
#    DEBUG  >  __init__()  >  geometry_3D.py:99    >  Interpolating 3D B_Y profile took 2.378591775894165 s
#    DEBUG  >  __init__()  >  geometry_3D.py:104   >  Interpolating 3D B_Z profile took 5.047364950180054 s
#    DEBUG  >  __init__()  >  geometry_3D.py:109   >  Interpolating 3D poloidal flux profile took 5.001858234405518 s
#    DEBUG  >  create_magnetic_geometry_3D()  >  geometry_3D.py:238   >  Converting the field profile took 16.174278020858765 s
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:237   >
#
#     ##################################################
#     #
#     # LAUNCH ROUTINE
#     #
#     ##################################################
#
#     INFO  >  find_plasma_entry_position()  >  launch_3D.py:23    >  Finding plasma entry position
#    DEBUG  >  _find_plasma_root()  >  launch_3D.py:92    >  Unable to find any roots with `tau_max` = 0.5 with error: attempt to get argmin of an empty sequence
#    DEBUG  >  _find_plasma_root()  >  launch_3D.py:98    >
#         ##################################################
#         #
#         # Finding plasma entry position. Trying:
#         #   - Launch position [X,Y,Z] = [ 3.01346,  0.     , -0.09017]
#         #   - tau = 0 to 0.5
#         #   - poloidal_flux_enter = 0.95
#         #   - poloidal flux along the ray line =
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.73905717 2.73905717 2.73905717]
#         #        [2.73905717 2.73905717 2.70093268 2.66218285 2.62279927]
#         #   - (Cubic) spline roots = None
#         #   - Selected root = None
#         #   - Position of selected root [X,Y,Z] = None
#         #   - Poloidal flux position of selected root = None
#         #
#         ##################################################
#
#     INFO  >  find_plasma_entry_position()  >  launch_3D.py:123   >  No root found for `tau_max` = 0.5
#    DEBUG  >  _find_plasma_root()  >  launch_3D.py:98    >
#         ##################################################
#         #
#         # Finding plasma entry position. Trying:
#         #   - Launch position [X,Y,Z] = [ 3.01346,  0.     , -0.09017]
#         #   - tau = 0 to 1.0
#         #   - poloidal_flux_enter = 0.95
#         #   - poloidal flux along the ray line =
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.6538818  2.59132397 2.52721019 2.46157755 2.39445697]
#         #        [2.32586984 2.25583802 2.18438963 2.11155434 2.03735383 1.96180946]
#         #        [1.88495271 1.80680653 1.72737332 1.64670106 1.56482787 1.48164571]
#         #        [1.39741383 1.31189913 1.22490845 1.13796031 1.04777629 0.96177548]
#         #        [0.8977601  0.84561772 0.79575958 0.75077534 0.70888708 0.66952219]
#         #        [0.6327815  0.59809289 0.56534589 0.53437753 0.50501836 0.47717471]
#         #        [0.45073086 0.42559977 0.40169929 0.37895069 0.35729453 0.33667375]
#         #        [0.31702567 0.29829449 0.28044071 0.26342626 0.24720773]
#         #        [0.23174088 0.21698705 0.20291866 0.18951251 0.17673814]
#         #   - (Cubic) spline roots = [0.71878932]
#         #   - Selected root = 0.7187893195097182
#         #   - Position of selected root [X,Y,Z] = [ 2.3000284e+00,  8.7370169e-17, -2.5716176e-03]
#         #   - Poloidal flux position of selected root = 0.9499288355060086
#         #
#         ##################################################
#
#    DEBUG  >  _find_plasma_root()  >  launch_3D.py:98    >
#         ##################################################
#         #
#         # Finding plasma entry position. Trying:
#         #   - Launch position [X,Y,Z] = [ 3.01346,  0.     , -0.09017]
#         #   - tau = 0 to 1.0
#         #   - poloidal_flux_enter = 0.95
#         #   - poloidal flux along the ray line =
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.71486767 2.71486767 2.71486767 2.71486767 2.71486767]
#         #        [2.71486767 2.6538818  2.59132397 2.52721019 2.46157755 2.39445697]
#         #        [2.32586984 2.25583802 2.18438963 2.11155434 2.03735383 1.96180946]
#         #        [1.88495271 1.80680653 1.72737332 1.64670106 1.56482787 1.48164571]
#         #        [1.39741383 1.31189913 1.22490845 1.13796031 1.04777629 0.96177548]
#         #        [0.8977601  0.84561772 0.79575958 0.75077534 0.70888708 0.66952219]
#         #        [0.6327815  0.59809289 0.56534589 0.53437753 0.50501836 0.47717471]
#         #        [0.45073086 0.42559977 0.40169929 0.37895069 0.35729453 0.33667375]
#         #        [0.31702567 0.29829449 0.28044071 0.26342626 0.24720773]
#         #        [0.23174088 0.21698705 0.20291866 0.18951251 0.17673814]
#         #   - (Cubic) spline roots = [0.71878932]
#         #   - Selected root = 0.7187893195097182
#         #   - Position of selected root [X,Y,Z] = [ 2.3000284e+00,  8.7370169e-17, -2.5716176e-03]
#         #   - Poloidal flux position of selected root = 0.9499288355060086
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_position()  >  launch_3D.py:152   >  Plasma entry position, `q_initial_cartesian`, is [X,Y,Z] = [ 2.3000384e+00,  8.7368953e-17, -2.5728367e-03]
#     INFO  >  find_auto_delta_signs()  >  launch_3D.py:165   >  Setting delta signs
#    DEBUG  >  find_auto_delta_signs()  >  launch_3D.py:169   >  Switched delta_X from -0.001 to 0.001
#    DEBUG  >  find_auto_delta_signs()  >  launch_3D.py:177   >  Switched delta_Z from 0.001 to -0.001
#     INFO  >  initialise_hamiltonians()  >  hamiltonian_3D.py:331   >  Initialising the Hamiltonians with `mode_flag`s = +1 and -1
#    DEBUG  >  __init__()  >  hamiltonian_3D.py:163   >
#         ##################################################
#         #
#         # Creating Hamiltonian with:
#         #   - mode_flag = 1
#         #   - w_launch = 455530934770.52
#         #   - K_launch = 1519.4876409149692
#         #   - (finite difference) spacings = {'X': 0.001, 'Y': 0.001, 'Z': -0.001, 'K_X': -0.1, 'K_Y': 0.1, 'K_Z': 0.1}
#         #   - field type = <class 'scotty.geometry_3D.InterpolatedField_3D_Cartesian'>
#         #   - density fit type = <class 'scotty.profile_fit.SmoothingSplineFit'>
#         #   - temperature fit type = <class 'NoneType'>
#         #
#         ##################################################
#
#    DEBUG  >  __init__()  >  hamiltonian_3D.py:163   >
#         ##################################################
#         #
#         # Creating Hamiltonian with:
#         #   - mode_flag = -1
#         #   - w_launch = 455530934770.52
#         #   - K_launch = 1519.4876409149692
#         #   - (finite difference) spacings = {'X': 0.001, 'Y': 0.001, 'Z': -0.001, 'K_X': -0.1, 'K_Y': 0.1, 'K_Z': 0.1}
#         #   - field type = <class 'scotty.geometry_3D.InterpolatedField_3D_Cartesian'>
#         #   - density fit type = <class 'scotty.profile_fit.SmoothingSplineFit'>
#         #   - temperature fit type = <class 'NoneType'>
#         #
#         ##################################################
#
#     INFO  >  find_plasma_entry_parameters()  >  launch_3D.py:202   >  Finding plasma entry parameters
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:217   >
#         ##################################################
#         #
#         # Finding plasma entry parameters with:
#         #   - vacuumLaunch_flag = True
#         #   - vacuum_propagation_flag = True
#         #   - Psi_BC_flag = discontinuous
#         #   - mode_flag (at launch, from user) = X
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:366   >  `vacuumLaunch_flag` and `vacuum_propagation_flag` are True. Launching from outside the plasma
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:387   >  `Psi_BC_flag` is discontinuous. Applying boundary conditions to find K and Psi
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:399   >
#         ##################################################
#         #
#         # Calculated values at [X,Y,Z] = [ 2.3000384e+00,  8.7368953e-17, -2.5728367e-03]:
#         #   - poloidal flux = 0.9499999999999128
#         #   - n_e = 0.5889557072626773 (e19)
#         #   - T_e = None
#         #   - |B| = 1.3618275977680312
#         #   - b_hat = [ 0.0125878, -0.9832737, -0.1816984]
#         #   - epsilon_11 = 0.8751539911826351
#         #   - epsilon_12 = 0.06564479814286521
#         #   - epsilon_bb = 0.9096704291852423
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:426   >  `mode_flag` is X. Applying boundary conditions for Hamiltonian with `mode_flag` = 1
#    DEBUG  >  apply_discontinuous_BC_3D()  >  boundary_conditions_3D.py:639   >  Applying discontinuous boundary conditions
#    DEBUG  >  find_K_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:280   >
#         Finding K at the plasma entry point with discontinuous boundary conditions
#         ##################################################
#         #
#         # Calculated at [X,Y,Z] = [ 2.3000384e+00,  8.7368953e-17, -2.5728367e-03]:
#         #   - B_X = 0.017142432790562358
#         #   - B_Y = -1.3390493209641647
#         #   - B_Z = -0.24744182966118988
#         #   - |B| = 1.3618275977680312
#         #
#         #   - w_pe / w_launch = 0.30054878275374486
#         #   - w_ce / w_launch = 0.5258061412191068
#         #   - w_L  / w_launch = 0.1364058265498882
#         #   - w_R  / w_launch = 0.662211967768995
#         #   - w_UH / w_launch = 0.6056415350341199
#         #
#         #   - d(polflux)/dX = 7.224344069562627
#         #   - d(polflux)/dY = -2.6645352591003757e-12
#         #   - d(polflux)/dZ = 0.4503468072960537
#         #
#         ##################################################
#
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:454   >
#         Finding Psi at the plasma entry point with discontinuous boundary conditions
#         ##################################################
#         #
#         # Derivatives at [X,Y,Z] = [ 2.3000384e+00,  8.7368953e-17, -2.5728367e-03] with K_plasma = [-1.4368637e+03, -2.6296622e-11,  1.8962349e+02]:
#         #   - dH/dX = -17.073689317692043
#         #   - dH/dY = -0.0025062486139204587
#         #   - dH/dZ = -1.049611543220641
#         #   - dH/dKx = -0.0012447566661816234
#         #   - dH/dKy = -4.011391837588363e-06
#         #   - dH/dKz = 0.00016353656214884715
#         #
#         #   - d(polflux)/dX = 7.224344069562627
#         #   - d(polflux)/dY = -2.6645352591003757e-12
#         #   - d(polflux)/dZ = 0.4503468072960537
#         #
#         #   - d2(polflux)/dX2 = 266.8019925538001
#         #   - d2(polflux)/dY2 = 3.1637635899972594
#         #   - d2(polflux)/dZ2 = 10.423665402603532
#         #   - d2(polflux)/dXdY = 1.1102230246251565e-10
#         #   - d2(polflux)/dXdZ = 10.294737759264372
#         #   - d2(polflux)/dYdZ = -5.551115123125783e-11
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:536   >
#         #
#         #   - interface matrix =
#         #        [7.0997481e-24, 3.8499039e-11, 0.0000000e+00, 5.2191147e+01, 0.0000000e+00,
#  0.0000000e+00]
#         #        [ 0.2028122,  0.       , -6.5069206,  0.       ,  0.       , 52.1911472]
#         #        [ 0.2028122,  0.4056245, -6.5069206,  0.2028122, -6.5069206, 52.1911472]
#         #        [-1.2447567e-03, -4.0113918e-06,  1.6353656e-04,  0.0000000e+00,
#   0.0000000e+00,  0.0000000e+00]
#         #        [ 0.0000000e+00, -1.2447567e-03,  0.0000000e+00, -4.0113918e-06,
#   1.6353656e-04,  0.0000000e+00]
#         #        [ 0.0000000e+00,  0.0000000e+00, -1.2447567e-03,  0.0000000e+00,
#  -4.0113918e-06,  1.6353656e-04]
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:554   >
#         #
#         #   - interface matrix inverse =
#         #        [-3.1179932e-07,  2.0391364e-04,  1.3229349e-04, -8.0331509e+02,
#   2.6318984e+00, -1.0729733e+02]
#         #        [ 1.6852022e-05,  2.0357591e-02, -2.0357591e-02, -2.4668261e-12,
#  -8.1000373e+02,  3.9556824e-11]
#         #        [-1.9598933e-06,  2.0514381e-03,  5.0759861e-04,  4.1695216e-01,
#   1.6406570e-01, -8.1669236e+02]
#         #        [ 1.9160338e-02, -1.5016870e-14,  1.5016870e-14,  1.1109749e-22,
#   5.9750296e-10, -1.4583234e-23]
#         #        [ 5.9825330e-04,  1.5495157e-01, -1.5495157e-01, -1.8776219e-11,
#  -5.0493524e+01,  3.0108631e-10]
#         #        [-2.4313766e-07,  1.9415308e-02,  6.2770666e-05,  3.1736266e+00,
#   1.0227429e-02, -1.0140400e+02]
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:575   >
#         #
#         #   - eta_XY  = -1.5818817949986297
#         #   - eta_XZ  = -5.068778268145754
#         #   - eta_XYZ = -5.074901588548846
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:590   >
#         #
#         #   - RHS vector =
#         #        -224229.81879997224 + 62669.32688249058j
#         #        -213869.86516866562 + 60797.067986629j
#         #        -214741.21128309553 + 61040.59792731811j
#         #        17.073689317692043
#         #        0.0025062486139204587
#         #        1.049611543220641
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:608   >
#         #
#         #   - Psi_3D_plasma_labframe_cartesian
#         #        Psi_XX_p = -13900.116114671511 + 20.4530848168298j
#         #        Psi_XY_p = 11.929710941751804 + -3.901577963849377j
#         #        Psi_XZ_p = -1397.3940689237138 + 155.582718490864j
#         #        Psi_YY_p = -4296.31902492032 + 1200.765459318242j
#         #        Psi_YZ_p = 0.743667131341271 + -0.2432142160650983j
#         #        Psi_ZZ_p = -4218.023463075619 + 1184.2101106441044j
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:455   >
#         ##################################################
#         #
#         # Calculated values for Hamiltonian with `+1`:
#         #   - K_initial_cartesian = [-1.4368637e+03, -2.6296622e-11,  1.8962349e+02]
#         #
#         #   - Psi_3D_initial_labframe_cartesian =
#         #        [[-1.3900116e+04 +20.4530848j,  1.1929711e+01  -3.901578j ,
#  -1.3973941e+03+155.5827185j],
#         #         [ 1.1929711e+01-3.9015780e+00j, -4.2963190e+03+1.2007655e+03j,
#   7.4366713e-01-2.4321422e-01j],
#         #         [-1.3973941e+03+1.5558272e+02j,  7.4366713e-01-2.4321422e-01j,
#  -4.2180235e+03+1.1842101e+03j]]
#         #
#         #   - theta_m (in radians) = -0.036260239666276846
#         #   - theta_m (in degrees) = -2.0775586970105198
#         #
#         #   - H[0] = -0.03948406413328395
#         #   - e_hat[0] = [-7.3700964e-02+0.0000000e+00j, -1.1102230e-16+9.9548149e-01j,
#  -5.9872945e-02-3.4694470e-17j]
#         #
#         #   - H[1] = -1.129408445613088e-14
#         #   - e_hat[1] = [-0.0329298+0.0000000e+00j,  0.       -6.2432670e-02j,
#  -0.9975058+4.1633363e-17j]
#         #
#         #   - H[2] = 0.8799064551904344
#         #   - e_hat[2] = [-0.9967366+0.j       ,  0.       -0.0715455j,  0.0373824+0.j       ]
#         #
#         #   - mode_index = 1
#         #   - selected H = -1.129408445613088e-14
#         #   - selected e_hat = [-0.0329298+0.0000000e+00j,  0.       -6.2432670e-02j,
#  -0.9975058+4.1633363e-17j]
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:493   >  `mode_flag` is X. Applying boundary conditions for Hamiltonian with `mode_flag` = -1
#    DEBUG  >  apply_discontinuous_BC_3D()  >  boundary_conditions_3D.py:639   >  Applying discontinuous boundary conditions
#    DEBUG  >  find_K_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:280   >
#         Finding K at the plasma entry point with discontinuous boundary conditions
#         ##################################################
#         #
#         # Calculated at [X,Y,Z] = [ 2.3000384e+00,  8.7368953e-17, -2.5728367e-03]:
#         #   - B_X = 0.017142432790562358
#         #   - B_Y = -1.3390493209641647
#         #   - B_Z = -0.24744182966118988
#         #   - |B| = 1.3618275977680312
#         #
#         #   - w_pe / w_launch = 0.30054878275374486
#         #   - w_ce / w_launch = 0.5258061412191068
#         #   - w_L  / w_launch = 0.1364058265498882
#         #   - w_R  / w_launch = 0.662211967768995
#         #   - w_UH / w_launch = 0.6056415350341199
#         #
#         #   - d(polflux)/dX = 7.224344069562627
#         #   - d(polflux)/dY = -2.6645352591003757e-12
#         #   - d(polflux)/dZ = 0.4503468072960537
#         #
#         ##################################################
#
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:454   >
#         Finding Psi at the plasma entry point with discontinuous boundary conditions
#         ##################################################
#         #
#         # Derivatives at [X,Y,Z] = [ 2.3000384e+00,  8.7368953e-17, -2.5728367e-03] with K_plasma = [-1.4043280e+03, -3.8296670e-11,  1.9165168e+02]:
#         #   - dH/dX = -25.644504998398432
#         #   - dH/dY = 0.0035232871989365755
#         #   - dH/dZ = -1.5707023615258442
#         #   - dH/dKx = -0.001216336340710833
#         #   - dH/dKy = 5.770464649446083e-06
#         #   - dH/dKz = 0.0001670522880015124
#         #
#         #   - d(polflux)/dX = 7.224344069562627
#         #   - d(polflux)/dY = -2.6645352591003757e-12
#         #   - d(polflux)/dZ = 0.4503468072960537
#         #
#         #   - d2(polflux)/dX2 = 266.8019925538001
#         #   - d2(polflux)/dY2 = 3.1637635899972594
#         #   - d2(polflux)/dZ2 = 10.423665402603532
#         #   - d2(polflux)/dXdY = 1.1102230246251565e-10
#         #   - d2(polflux)/dXdZ = 10.294737759264372
#         #   - d2(polflux)/dYdZ = -5.551115123125783e-11
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:536   >
#         #
#         #   - interface matrix =
#         #        [7.0997481e-24, 3.8499039e-11, 0.0000000e+00, 5.2191147e+01, 0.0000000e+00,
#  0.0000000e+00]
#         #        [ 0.2028122,  0.       , -6.5069206,  0.       ,  0.       , 52.1911472]
#         #        [ 0.2028122,  0.4056245, -6.5069206,  0.2028122, -6.5069206, 52.1911472]
#         #        [-1.2163363e-03,  5.7704646e-06,  1.6705229e-04,  0.0000000e+00,
#   0.0000000e+00,  0.0000000e+00]
#         #        [ 0.0000000e+00, -1.2163363e-03,  0.0000000e+00,  5.7704646e-06,
#   1.6705229e-04,  0.0000000e+00]
#         #        [ 0.0000000e+00,  0.0000000e+00, -1.2163363e-03,  0.0000000e+00,
#   5.7704646e-06,  1.6705229e-04]
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:554   >
#         #
#         #   - interface matrix inverse =
#         #        [ 1.2304464e-06,  5.7142033e-04, -2.0374114e-04, -8.2207971e+02,
#  -3.9680014e+00, -1.1487181e+02]
#         #        [ 1.7441262e-04,  2.1289107e-02, -2.1289107e-02, -2.6409674e-12,
#  -8.2924052e+02,  4.2349269e-11]
#         #        [ 2.9343798e-06,  3.4252226e-03, -7.4808743e-04,  4.4638624e-01,
#  -2.4735488e-01, -8.3640133e+02]
#         #        [ 1.9160338e-02, -1.5704007e-14,  1.5704007e-14,  1.1377856e-22,
#   6.1169307e-10, -1.5612710e-23]
#         #        [ 6.0807522e-04,  1.5500964e-01, -1.5500964e-01, -1.9229336e-11,
#  -5.1692696e+01,  3.0835228e-10]
#         #        [ 3.6106174e-07,  1.9585156e-02, -9.2475919e-05,  3.2502147e+00,
#  -1.5419460e-02, -1.0383178e+02]
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:575   >
#         #
#         #   - eta_XY  = -1.5818817949986297
#         #   - eta_XZ  = -5.068778268145754
#         #   - eta_XYZ = -5.074901588548846
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:590   >
#         #
#         #   - RHS vector =
#         #        -223486.17941664116 + 62669.32688249058j
#         #        -211477.783383078 + 60797.067986629j
#         #        -212346.23975121623 + 61040.59792731811j
#         #        25.644504998398432
#         #        -0.0035232871989365755
#         #        1.5707023615258442
#         #
#    DEBUG  >  find_Psi_3D_plasma_with_discontinuous_BC()  >  boundary_conditions_3D.py:608   >
#         #
#         #   - Psi_3D_plasma_labframe_cartesian
#         #        Psi_XX_p = -21340.096783719975 + 22.381310711434324j
#         #        Psi_XY_p = -17.568497089545104 + 5.7457865494618545j
#         #        Psi_XZ_p = -1868.450048000844 + 162.76368338411362j
#         #        Psi_YY_p = -4282.070643293876 + 1200.7654593182347j
#         #        Psi_YZ_p = -1.0951743859007395 + 0.3581773795613117j
#         #        Psi_ZZ_p = -4202.007774889253 + 1185.0979029772234j
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:522   >
#         ##################################################
#         #
#         # Calculated values for Hamiltonian with `-1`:
#         #   - K_initial_cartesian = [-1.4043280e+03, -3.8296670e-11,  1.9165168e+02]
#         #
#         #   - Psi_3D_initial_labframe_cartesian =
#         #        [[-2.1340097e+04 +22.3813107j, -1.7568497e+01  +5.7457865j,
#  -1.8684500e+03+162.7636834j],
#         #         [-1.7568497e+01+5.7457865e+00j, -4.2820706e+03+1.2007655e+03j,
#  -1.0951744e+00+3.5817738e-01j],
#         #         [-1.8684500e+03+1.6276368e+02j, -1.0951744e+00+3.5817738e-01j,
#  -4.2020078e+03+1.1850979e+03j]]
#         #
#         #   - theta_m (in radians) = -0.037049708049772784
#         #   - theta_m (in degrees) = -2.1227919034438525
#         #
#         #   - H[0] = -2.453508734999254e-15
#         #   - e_hat[0] = [-7.6989830e-02+0.0000000e+00j,  1.1102230e-16+9.9517689e-01j,
#  -6.0790777e-02-6.9388939e-18j]
#         #
#         #   - H[1] = 0.039706752912061584
#         #   - e_hat[1] = [-0.0335074+0.0000000e+00j,  0.       -6.3519900e-02j,
#  -0.9974179-2.7755576e-17j]
#         #
#         #   - H[2] = 0.8801206280723741
#         #   - e_hat[2] = [-0.9964687+0.0000000e+00j,  0.       -7.4754096e-02j,
#   0.0382361-3.5778672e-18j]
#         #
#         #   - mode_index = 0
#         #   - selected H = -2.453508734999254e-15
#         #   - selected e_hat = [-7.6989830e-02+0.0000000e+00j,  1.1102230e-16+9.9517689e-01j,
#  -6.0790777e-02-6.9388939e-18j]
#         #
#         ##################################################
#
#    DEBUG  >  find_plasma_entry_parameters()  >  launch_3D.py:612   >
#         ##################################################
#         #
#         # Calculated plasma entry parameters for:
#         #   - X-mode (selected):
#         #        - K = [-1.4043280e+03, -3.8296670e-11,  1.9165168e+02]
#         #
#         #        - Psi_3D =
#         #             [[-2.1340097e+04 +22.3813107j, -1.7568497e+01  +5.7457865j,
#  -1.8684500e+03+162.7636834j],
#         #              [-1.7568497e+01+5.7457865e+00j, -4.2820706e+03+1.2007655e+03j,
#  -1.0951744e+00+3.5817738e-01j],
#         #              [-1.8684500e+03+1.6276368e+02j, -1.0951744e+00+3.5817738e-01j,
#  -4.2020078e+03+1.1850979e+03j]]
#         #
#         #        - mode_flag = -1
#         #
#         #        - mode_index = 0
#         #
#         #        - H = -2.453508734999254e-15
#         #
#         #        - e_hat = [-7.6989830e-02+0.0000000e+00j,  1.1102230e-16+9.9517689e-01j,
#  -6.0790777e-02-6.9388939e-18j]
#         #
#         #   - O-mode (not selected):
#         #        - K = [-1.4368637e+03, -2.6296622e-11,  1.8962349e+02]
#         #
#         #        - Psi_3D =
#         #             [[-1.3900116e+04 +20.4530848j,  1.1929711e+01  -3.901578j ,
#  -1.3973941e+03+155.5827185j],
#         #              [ 1.1929711e+01-3.9015780e+00j, -4.2963190e+03+1.2007655e+03j,
#   7.4366713e-01-2.4321422e-01j],
#         #              [-1.3973941e+03+1.5558272e+02j,  7.4366713e-01-2.4321422e-01j,
#  -4.2180235e+03+1.1842101e+03j]]
#         #
#         #        - mode_flag = 1
#         #
#         #        - mode_index = 1
#         #
#         #        - H = -1.129408445613088e-14
#         #
#         #        - e_hat = [-0.0329298+0.0000000e+00j,  0.       -6.2432670e-02j,
#  -0.9975058+4.1633363e-17j]
#         #
#         ##################################################
#
#     INFO  >  assign_hamiltonians()  >  hamiltonian_3D.py:369   >  Assigning the correct Hamiltonian corresponding to `mode_flag` = X
#    DEBUG  >  assign_hamiltonians()  >  hamiltonian_3D.py:374   >
#         ##################################################
#         #
#         # For [X,Y,Z] = [ 2.3000384e+00,  8.7368953e-17, -2.5728367e-03] and K = [-1.4043280e+03, -3.8296670e-11,  1.9165168e+02]:
#         #   - H (mode_flag +1) = -0.03970720969072683
#         #   - H (mode_flag -1) = 7.438494264988549e-15
#         #   - H tolerance      = 1e-05
#         #
#         ##################################################
#
#    DEBUG  >  assign_hamiltonians()  >  hamiltonian_3D.py:408   >  Hamiltonian with computed `mode_flag` = -1 selected for user-passed `mode_flag` = X
#     INFO  >  check_input_before_ray_tracing()  >  checks_3D.py:326   >  Checking the validity of user-specified arguments
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:328   >
#
#     ##################################################
#     #
#     # RAY TRACING ROUTINE
#     #
#     ##################################################
#
#     INFO  >  propagate_ray()  >  ray_solver_3D.py:394   >  Starting the ray solver
#     INFO  >  propagate_ray()  >  ray_solver_3D.py:411   >
#
#         Ray solver status: 1
#         Ray solver took 1.1694262027740479 s
#         Number of ray evolution evaluations: 194
#         Time per ray evolution evaluation: 0.0060279701173919994
#
#     INFO  >  handle_leaving_plasma_events()  >  ray_solver_3D.py:185   >
#
#         Ray has left plasma
#
#     INFO  >  handle_no_resonance()  >  ray_solver_3D.py:273   >  Starting the ray solver to find the cut-off
#     INFO  >  handle_no_resonance()  >  ray_solver_3D.py:287   >
#
#         Ray solver cut-off finder status: 0
#         Ray solver took 0.19014215469360352 s
#         Number of ray evolution evaluations: 32
#         Time per ray evolution evaluation: 0.00594194233417511
#
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:355   >
#
#     ##################################################
#     #
#     # BEAM TRACING ROUTINE
#     #
#     ##################################################
#
#     INFO  >  evolve_beam()  >  fun_evolution_3D.py:135   >  Starting the beam solver
#     INFO  >  evolve_beam()  >  fun_evolution_3D.py:151   >
#
#         Beam solver status: 0
#         Beam solver took 16.80758237838745 s
#         Number of beam evolution evaluations: 518
#         Time per beam evolution evaluation: 0.0324470702285472
#
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:390   >
#
#     ##################################################
#     #
#     # DATA SAVING ROUTINE
#     #
#     ##################################################
#
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:517   >
#
#     ##################################################
#     #
#     # DATA ANALYSIS ROUTINE
#     #
#     # Process the data from the main loop to give a
#     # bunch of useful stuff
#     #
#     ##################################################
#
#     INFO  >  beam_tracing_analysis_3D()  >  analysis_3D.py:45    >
#
#         ##################################################
#         #
#         # RAY AND BEAM TRACING ANALYSIS ROUTINE
#         #
#         ##################################################
#
#    DEBUG  >  beam_tracing_analysis_3D()  >  analysis_3D.py:53    >  Performing analysis on ray tracing results
#    DEBUG  >  beam_tracing_analysis_3D()  >  analysis_3D.py:101   >  Performing analysis on beam tracing results
#     INFO  >  analysis_dbs()  >  analysis_dbs_3D.py:28    >
#
#         ##################################################
#         #
#         # DOPPLER BACKSCATTERING ANALYSIS ROUTINE
#         #
#         ##################################################
#
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:36    >  Performing doppler backscattering analysis
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:81    >  Finding the wavenumber resolution and mismatch attenuation
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:97    >  Finding the polarisation piece (loc_p)
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:129   >  Finding the ray piece (loc_r)
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:166   >  Finding the beam piece (loc_b)
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:178   >  Finding the mismatch piece (loc_m)
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:185   >  Finding the spectrum piece (loc_s)
#    DEBUG  >  analysis_dbs()  >  analysis_dbs_3D.py:192   >  Finding total localisation (loc_p * loc_r * loc_b * loc_m * loc_s)
# Plotting and saving data
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:575   >  Figures saved to
#         C:\Users\eduar\OneDrive\OneDrive - EWIKARTA001\OneDrive - Nanyang Technological University\Work\Scotty Benchmarks\DIII-D shot 189998\cyl scotty
#     INFO  >  beam_me_up_3D()  >  beam_me_up_3D_temp.py:577   >
#
#     ##################################################
#     #
#     # FINISHED RUN !
#     #
#     ##################################################
#
# c:\Users\eduar\anaconda3\envs\scotty3dtest\lib\site-packages\matplotlib\cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\eduar\anaconda3\envs\scotty3dtest\lib\site-packages\matplotlib\cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# (<Figure size 1500x2000 with 15 Axes>,
#  array([[<Axes: title={'center': 'q_X'}>, <Axes: title={'center': 'q_Y'}>,
#          <Axes: title={'center': 'q_Z'}>],
#         [<Axes: title={'center': 'K_X'}>, <Axes: title={'center': 'K_Y'}>,
#          <Axes: title={'center': 'K_Z'}>],
#         [<Axes: title={'center': 'Principal Width 1'}>,
#          <Axes: title={'center': 'Principal Width 2'}>,
#          <Axes: title={'center': 'Principal Widths'}>],
#         [<Axes: title={'center': 'Principal Curvature 1'}>,
#          <Axes: title={'center': 'Principal Curvature 2'}>,
#          <Axes: title={'center': 'Principal Widths'}>],
#         [<Axes: title={'center': 'H_Cardano'}>, <Axes: >, <Axes: >]],
#        dtype=object))
